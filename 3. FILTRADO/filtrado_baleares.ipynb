# %%
import pandas as pd

# %%
df= pd.read_excel("C:/Users/USUARIO/TRABAJO DE FIN DE GRADO/CENTROS/1. DATOS EN CRUDO/asociaciones_baleares.xlsx")

# %%
df
# Out:
#                                          Denominación Fecha Inscripción  \
# 0                            Adopta un Amigo Mallorca        2019-04-01
# 1              Agrupació d'Amics dels Cavalls de Muro        2021-06-23
# 2   Agrupació de Defensa Sanitaria Apícola Amics A...        2022-05-04
# 3                                Alcudia Cats Friends        2020-06-03
# 4                   Amics dels Cavalls i les Muntures        2019-03-04
# 5                        Amigos del Caballo El Corcel        2021-06-15
# 6                                              Apcans        2022-10-26
# 7       Asociación Amigos del Pastor Alemán de Campos        2021-05-25
# 8         Asociación Amigos del Pastor Alemán de Inca        2021-03-23
# 9                    Asociación Animal de Son Servera        2022-10-14
# 10                             Asociación Animal Team        2020-06-08
# 11        Asociación Animalista de Ibiza y Formentera        2021-06-15
# ...

# %%
# Guardar DataFrame en un archivo de Excel
df.to_excel('filtrado_baleares.xlsx', index=False)
