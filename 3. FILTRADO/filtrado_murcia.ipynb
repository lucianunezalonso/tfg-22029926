# %%
import pandas as pd

# %%
df= pd.read_excel("C:/Users/USUARIO/TRABAJO DE FIN DE GRADO/CENTROS/1. DATOS EN CRUDO/asociaciones_murcia.xlsx")

# %%
df
# Out:
#                      Municipio  \
# 0                     ABANILLA
# 1                       ABARAN
# 2                      AGUILAS
# 3                      AGUILAS
# 4                      AGUILAS
# ..                         ...
# 186                      UNION
# 187                      UNION
# 188  VILLANUEVA DEL RIO SEGURA
# 189                      YECLA
# 190                      YECLA
#
#                                                 Nombre  \
# 0    A.P.A.M.A. NATURE (ASOCIACION PARA LA PROTECCI...
# 1             ASOCIACION "POR UN AMIGO FIEL" DE ABARAN
# 2                           SANTOLINA ANIMAL SANTUARIO
# 3                      ASOCIACION PROYECTO CES AGUILAS
# 4             ASOCIACION PROTECTORES NUEVA ERA AGUILAS
# ..                                                 ...
# 186  ASOCIACION PROTECTORA DE ANIMALES "LA CASITA D...
# 187                        ASOCIACION UNION ANIMALISTA
# 188  UNIDAD CANINA DE RESCATE Y SALVAMENTO VILLANUE...
# ...

# %%
list(df['Nombre'])
# Out:
# ['A.P.A.M.A. NATURE (ASOCIACION PARA LA PROTECCION DE LOS ANIMALES Y EL MEDIO AMBIENTE)',
#  'ASOCIACION "POR UN AMIGO FIEL" DE ABARAN',
#  'SANTOLINA ANIMAL SANTUARIO',
#  'ASOCIACION PROYECTO CES AGUILAS',
#  'ASOCIACION PROTECTORES NUEVA ERA AGUILAS',
#  'ASOCIACION ANIMALES EN APUROS AGUILAS',
#  '-AGUIPROAN- AGUILAS PROTECCION ANIMALES',
#  'ASOCIACION PARA LA PROTECCION Y DEFENSA DE ANIMALES Y PLANTAS "PROTECTORA KANAAN"',
#  'ASOCIACION CANINA AMIGOS DE LOS PERROS DE ALCANTARILLA (A.C.A.P.A.)',
#  'ASOCIACION PROTECTORA FELINA GATOKU',
#  'ADOPTA MARAVILLAS, ASOCIACIÓN PROTECTORA DE ANIMALES Y MEDIO AMBIENTE',
#  'ASOCIACION DE CRIADORES DE AVES FRINGILIDAS LOS ALCAZARES (A.C.A.F.A.)',
#  'ASOCIACION MYPU',
#  'ASOCIACION PATITAS UNIDAS LOS ALCAZARES',
#  'ASOCIACIÓN GATOS LOS ALCÁZARES (AGATA)',
#  'ASOCIACION TOP DOG CLUB',
#  'ASOCIACION EL LOCO DE LOS PERROS',
#  'ASOCIACION PROTECTORA DEL GALGO, GALGO-KEEPER',
#  'ASOCIACION ENGATUSATE ALHAMA DE MURCIA',
# ...

# %%
# Guardar DataFrame en un archivo de Excel
df.to_excel('filtrado_murcia.xlsx', index=False)
