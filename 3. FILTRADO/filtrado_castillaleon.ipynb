# %% [markdown]
# http://datosabiertos.jcyl.es/web/jcyl/set/es/otros/asociaciones/1284273543253

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel("./DATOS INICIALES/asociaciones_castillaleon.xlsx")

# %%
df
# Out:
#            Num_Asoc      Ambito  \
# 0      05/1/0000002    COMARCAL
# 1      05/1/0000005  PROVINCIAL
# 2      05/1/0000007       LOCAL
# 3      05/1/0000008       LOCAL
# 4      05/1/0000010       LOCAL
# ...             ...         ...
# 36310  49/3/0000612       LOCAL
# 36311  49/3/0000613  PROVINCIAL
# 36312  49/3/0000614       LOCAL
# 36313  49/3/0000615       LOCAL
# 36314  49/3/0000616       LOCAL
#
#                                               Asociación        Nif  \
# 0      ASOCIACION DE MADRES Y PADRES DE ALUMNOS DEL I...  G05006739
# 1      ASOCIACION CATOLICA DE MAESTROS DE LA PROVINCI...        NaN
# 2          SOCIEDAD CULTURAL Y DE RECREO PUERTO DEL PICO  G05112016
# 3                          CULTURAL DEPORTIVA CEBREREÑA         NaN
# 4                              PEÑA MADRIDISTA TEMBLEÑA         NaN
# ...                                                  ...        ...
# 36310              ASOCIACION JUVENIL RIOMANZANAS AL LIO        NaN
# ...

# %% [markdown]
# FUNCIONES:

# %%
# Crea un df con los registros en los que aparece el nombre que le digo
def extraer_por_palabra(df, palabra):
    df_palabra = df[df['Asociación'].str.lower().str.contains(palabra.lower())]
    return df_palabra

# %%
def eliminar_filas_listanegra(df, listanegra):
    # Crea una Serie booleana que indica si cada fila contiene alguna palabra de la lista negra
    mascara = df['Asociación'].str.contains('|'.join(listanegra), case=False)
    # Elimina las filas que cumplen la condición anterior
    df = df[~mascara]
    return df

# %%
def restar_df(df_minuendo, df_sustraendo):
    df_diferencia = df_minuendo.merge(df_sustraendo, how='outer', indicator=True)
    df_diferencia = df_diferencia.loc[df_diferencia['_merge'] == 'left_only'].drop(columns='_merge')
    return df_diferencia

# %% [markdown]
# EMPIEZO A FILTRAR:

# %%
# Creo df_ok para introducir en el los registros que me interesan y que en df se me vayan quedando los que no
df_ok= extraer_por_palabra(df,'animal')

# %%
df_ok
# Out:
#            Num_Asoc      Ambito  \
# 606    05/1/0000764       LOCAL
# 2075   05/1/0002393  PROVINCIAL
# 2085   05/1/0002403  PROVINCIAL
# 2218   05/1/0002543       LOCAL
# 2225   05/1/0002550  PROVINCIAL
# ...             ...         ...
# 35411  49/1/0002430  PROVINCIAL
# 35497  49/1/0002518       LOCAL
# 35602  49/1/0002632  PROVINCIAL
# 35896  49/1/0002927  PROVINCIAL
# 36087  49/1/0003119  PROVINCIAL
#
#                                               Asociación        Nif  \
# 606    ASOCIACION HUELLAS PROTECTORA DE ANIMALES DE A...  G05120217
# 2075         ASOCIACION PROTECTORA DE ANIMALES VILLAPEPA        NaN
# 2085   ASOCIACION DE TERAPIA ASISTIDA CON ANIMALES EQ...        NaN
# 2218        ASOCIACION PROTECTORA S.O.S ANIMAL LA ADRADA        NaN
# 2225   ASOCIACION PROTECTORA DE ANIMALES ANIMALES EN ...        NaN
# ...                                                  ...        ...
# 35411                              DEFENSA ANIMAL ZAMORA        NaN
# ...

# %%
df= restar_df(df, df_ok)

# %% [markdown]
# FILTRO DE LISTA NEGRA:

# %%
listanegra= ['cult','juv','fam','jov','teat','proy','alum','music','club','vec','educ','muj','cole','salud','depor',
             'peña','tau','tor','enfer','sindr','danz','ecuest','manos','caz','herm','folc','desarr','futb','filo',
            'geo','derma','astro','mater','lit','consum','grup','pad','mad','diab','psico','san','jubil','animacion',
             'escler','internet','cuchill','scout','banda','eco','toxic','casin','mayor','poe','encaje','disca','galleg',
            'aliment','comision','tuna','linux','celiac','dona','pensi','cient','capac','liceo','ruta','fray','guiri',
             'medio ambiente','igual','cienc','siest','multiav','capa','turis','foto','hum','comit','down',
             'moro','folk','urol','trans','drog','flame','profes','corriente','benef','hombr','social','atl','tamb',
             'renac','taller','reti','escue','fibr','comerc','servic','preadop','viud','coro','estud','canci','oper',
             'matri','creat','diver','perc','coch','roq','puebl','madre','liri','socr','fest','terap','chara','esc','quim',
             'fisi','usua','epilep','cabañ','cánc','empr','usu','sativ','canna','vide','idea','depr','tur','campo','espirit',
            'microbio','volunt','gremi','parapl','margi','alzhe','patrim','ingen','art','bail','anore','finca','encin',
            'ciudad','cafe','sosten','infant','copla','ajed','colomb','orque','concier','ruman','femen','gitan','audio',
            'produc','hipotec','caball','patin','polici','museo','robado','vehíc','jamon','músic','vino','gait','hist','montañ',
             'pedagog','ritmo','enolog','ocio','batuca','electron','parkou','sinfon','propie','bici','carne','radio','food',
            'cine','suicidi','tai chi','edad','femi','libro','porcin','rock','juego','peregr','medioamb','palestin','latin',
            'blog','lupus','parkins','ornito','viaje','a.m.p.a','trasplant','sordo','biblio','fitness','pediatr','infan',
            'mot','cicl','biomedi','electr','feria','tecnol','étni','vacun','alcoho','abogad','guitarr','medic','empl']

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 5867
# ['ASOCIACION CATOLICA DE MAESTROS DE LA PROVINCIA DE AVILA ',
#  'CIRCULO CANDELEDANO',
#  'PRONISA PLENA INCLUSIÓN ÁVILA',
#  'ASOCIACION DE MINUSVALIDOS ABULENSES AMA',
#  'ASOCIACION NUÑO COJO ',
#  'ASOCIACION FILATELICA AFILA ',
#  'ATOBAL',
#  'EL PIORNAL',
#  'LA TARASCA ',
#  'CEPA ',
#  'JIMENA BLAZQUEZ ',
#  'MOLINOS DE VIENTO ',
#  'ANDALUCIA DE AVILA ',
#  'DIEGO DE BRACAMONTE ',
#  'GALA ABULENSE ',
#  'LA PUERTA DE CASTILLA ',
#  'PE!A EL CASTILLO ',
#  'AL PIE DE LOS ALABES ',
#  'LUNETA TERMICA ',
#  'COMPARSA HARMONIA',
#  'MICOLOGICA ABULENSE',
#  'LA JARKA ',
#  'VIRGEN DE LA CUESTA ',
#  'ALAMEDA ',
#  'AMIGOS DE LA PARRA',
#  'ASOCIACION DE FIESTAS DE VERANO DE EL ARENAL ',
#  'PENA EL ESPARIBEL ',
#  'ASOCIACION DE AMIGOS DEL CAMPING DE PEGUERINOS ',
#  'PENA EL FURIA ',
#  'ASOCIACION DE MINUSVALIDOS ABULENSES VIRGEN DE SONSOLES ',
#  'LAS NAVAS DEL MARQUES ',
#  'ASOCIACION PRO-DEFENSA DE EL TREMEDAL ',
# ...

# %%
listanegra= ['pena','campi','dolor','amanec','iruela','laguna','cruz','trompa','carras','cogo','ceram','acorde','refu','amas',
            'gredo','alegr','virgen','ampa','castill','ganad','buho','ojo','GAVIOTA','patolog','cristo','prado','autism','pinar',
             'hipic','dominic','muralla','peru','aldea','vende','hiperac','bipola','pyme','rural','sahar','populo','cornej','candil',
             'sueña','sport','meraki','medit','UNIVERSIDAD','TELEFONO','PARALISIS','feliz','felix','felic','felipe']

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 5100
# ['ASOCIACION CATOLICA DE MAESTROS DE LA PROVINCIA DE AVILA ',
#  'CIRCULO CANDELEDANO',
#  'PRONISA PLENA INCLUSIÓN ÁVILA',
#  'ASOCIACION DE MINUSVALIDOS ABULENSES AMA',
#  'ASOCIACION FILATELICA AFILA ',
#  'ATOBAL',
#  'EL PIORNAL',
#  'LA TARASCA ',
#  'CEPA ',
#  'JIMENA BLAZQUEZ ',
#  'MOLINOS DE VIENTO ',
#  'ANDALUCIA DE AVILA ',
#  'DIEGO DE BRACAMONTE ',
#  'GALA ABULENSE ',
#  'AL PIE DE LOS ALABES ',
#  'LUNETA TERMICA ',
#  'COMPARSA HARMONIA',
#  'MICOLOGICA ABULENSE',
#  'LA JARKA ',
#  'ALAMEDA ',
#  'AMIGOS DE LA PARRA',
#  'ASOCIACION DE FIESTAS DE VERANO DE EL ARENAL ',
#  'LAS NAVAS DEL MARQUES ',
#  'ASOCIACION PRO-DEFENSA DE EL TREMEDAL ',
#  'ASOCIACION VEHICULOS CLASICOS VETERANOS AVILA ',
#  'LAS MORILLAS ',
#  'LAS NIEVES ',
#  'EL BUITRE GYPS FULVUS ',
#  'GUIA DE AVILA ',
#  'LA FUNDACION ',
#  'ASOCIACION FORESTAL DE AVILA',
#  'ASOCIACION LA ESTRELLA ',
#  'BEATRIZ DE SUABIA ',
#  'EL TOSTADO ',
#  'CARDIEL ',
#  'ADAJA ',
# ...

# %%
feli= extraer_por_palabra(df,'feli')

# %%
feli
# Out:
#            Num_Asoc      Ambito  \
# 2401   05/1/0002749  PROVINCIAL
# 7415   09/1/0005420       LOCAL
# 13526  24/1/0005980  PROVINCIAL
# 16346  34/1/0002525       LOCAL
# 16562  34/1/0002747  PROVINCIAL
# 21438  37/1/0004846       LOCAL
# 27519  42/1/0002371       LOCAL
# 29491  47/1/0002494  AUTONOMICO
# 31960  47/1/0005316  PROVINCIAL
# 32649  47/1/0006054  PROVINCIAL
#
#                                               Asociación        Nif  \
# 2401                                           FELINAVAS        NaN
# 7415   ASOCIACION FELINISAVE GESTION DE COLONIAS FELINAS  G09604265
# 13526  ASOCIACIÓN POR LA GESTIÓN ÉTICA DE LAS COLONIA...        NaN
# 16346              MIAU ASOCIACION FELINA PALENCIA (AFP)        NaN
# 16562                          SONRISAS FELINAS PALENCIA  G34286013
# 21438                        ASOCIACION CARBAJOSA FELINA        NaN
# 27519               ASOCIACION AFO AMIGOS FELINOS OLVEGA  G42895268
# ...

# %%
df= restar_df(df, feli)

# %%
df_ok = pd.concat([df_ok , feli], axis=0)

# %%
pets= extraer_por_palabra(df,'pets')
pets
# Out:
#          Num_Asoc      Ambito            Asociación  Nif  \
# 302  05/1/0002843  PROVINCIAL  ASOCIACION NAVALPETS  NaN
#
#                   Domicilio              Municipio Provincia C_Postal  Web  \
# 302  C/ Hermanos Machado, 5  NAVALPERAL DE PINARES     AVILA     5240  NaN
#
#                                                  Fines Fines_Específicos  \
# 302  Promover y realizar campañas de esterilización...               NaN
#
#               F_Registro Unnamed: 12
# 302  2022-05-13 00:00:00         NaT

# %%
df_ok = pd.concat([df_ok , pets], axis=0)

# %%
df= restar_df(df, pets)

# %%
huellas= extraer_por_palabra(df,'huellas')
huellas
# Out:
#           Num_Asoc      Ambito                                 Asociación  \
# 309   05/3/0000025  PROVINCIAL                                   HUELLAS
# 2429  34/1/0002736  PROVINCIAL  HUELLAS PALENCIA ASOCIACION ANTIESPECISTA
# 4438  47/1/0004818  PROVINCIAL                    ENTRE HUELLAS Y BIGOTES
# 4485  47/1/0004985  PROVINCIAL                    ASOCIACION VAYA HUELLAS
#
#       Nif                   Domicilio            Municipio   Provincia  \
# 309   NaN  PASEO DE SAN ROQUE,40-6-2                 ÁVILA       AVILA
# 2429  NaN           C/ Del Rio, nº 14  CERVERA DE PISUERGA    PALENCIA
# 4438  NaN      C/ TORRECILLA, 36-6º C           VALLADOLID  VALLADOLID
# 4485  NaN          C/ MIRABEL, 3-7º D           VALLADOLID  VALLADOLID
#
#      C_Postal                                Web  \
# 309      5000                                NaN
# 2429    34839  www.facebook.com/huellaspalencia/
# 4438    47003                                NaN
# ...

# %%
df_ok = pd.concat([df_ok , huellas], axis=0)

# %%
df= restar_df(df, huellas)

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 5085
# ['ASOCIACION CATOLICA DE MAESTROS DE LA PROVINCIA DE AVILA ',
#  'CIRCULO CANDELEDANO',
#  'PRONISA PLENA INCLUSIÓN ÁVILA',
#  'ASOCIACION DE MINUSVALIDOS ABULENSES AMA',
#  'ASOCIACION FILATELICA AFILA ',
#  'ATOBAL',
#  'EL PIORNAL',
#  'LA TARASCA ',
#  'CEPA ',
#  'JIMENA BLAZQUEZ ',
#  'MOLINOS DE VIENTO ',
#  'ANDALUCIA DE AVILA ',
#  'DIEGO DE BRACAMONTE ',
#  'GALA ABULENSE ',
#  'AL PIE DE LOS ALABES ',
#  'LUNETA TERMICA ',
#  'COMPARSA HARMONIA',
#  'MICOLOGICA ABULENSE',
#  'LA JARKA ',
#  'ALAMEDA ',
#  'AMIGOS DE LA PARRA',
#  'ASOCIACION DE FIESTAS DE VERANO DE EL ARENAL ',
#  'LAS NAVAS DEL MARQUES ',
#  'ASOCIACION PRO-DEFENSA DE EL TREMEDAL ',
#  'ASOCIACION VEHICULOS CLASICOS VETERANOS AVILA ',
#  'LAS MORILLAS ',
#  'LAS NIEVES ',
#  'EL BUITRE GYPS FULVUS ',
#  'GUIA DE AVILA ',
#  'LA FUNDACION ',
#  'ASOCIACION FORESTAL DE AVILA',
#  'ASOCIACION LA ESTRELLA ',
#  'BEATRIZ DE SUABIA ',
#  'EL TOSTADO ',
#  'CARDIEL ',
#  'ADAJA ',
# ...

# %%
listanegra= ['jóv','veter','cria','farmac','nauti','period','xarad','tierra','toy','nava','gota','lindi','cohe','habl',
             'trop','circul','anteñe','enseñ','apremnd','diseñ','ferroc','moda','abuel','micolo','pelicul','yoga','galeg','conserva',
             'paz','aguil','fenix','palenci','seneg','thal','cuadr','cercer','paraba','invest','elemen','urban','elefan','mentir',
             'minus','host','morc','energ','person','basket','vehic']

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 4591
# ['ASOCIACION CATOLICA DE MAESTROS DE LA PROVINCIA DE AVILA ',
#  'PRONISA PLENA INCLUSIÓN ÁVILA',
#  'ASOCIACION FILATELICA AFILA ',
#  'ATOBAL',
#  'EL PIORNAL',
#  'LA TARASCA ',
#  'CEPA ',
#  'JIMENA BLAZQUEZ ',
#  'MOLINOS DE VIENTO ',
#  'ANDALUCIA DE AVILA ',
#  'DIEGO DE BRACAMONTE ',
#  'GALA ABULENSE ',
#  'AL PIE DE LOS ALABES ',
#  'LUNETA TERMICA ',
#  'COMPARSA HARMONIA',
#  'LA JARKA ',
#  'ALAMEDA ',
#  'AMIGOS DE LA PARRA',
#  'ASOCIACION DE FIESTAS DE VERANO DE EL ARENAL ',
#  'ASOCIACION PRO-DEFENSA DE EL TREMEDAL ',
#  'LAS MORILLAS ',
#  'LAS NIEVES ',
#  'EL BUITRE GYPS FULVUS ',
#  'GUIA DE AVILA ',
#  'LA FUNDACION ',
#  'ASOCIACION FORESTAL DE AVILA',
#  'ASOCIACION LA ESTRELLA ',
#  'BEATRIZ DE SUABIA ',
#  'EL TOSTADO ',
#  'CARDIEL ',
#  'ADAJA ',
#  'PE A LOS TITULILLEROS ',
#  'ASOCIACION -LA TROMPETA ',
#  'ASOCIACION AMARI GOLE',
#  'AUTO CLASS OCHO DE AVILA ',
#  'CORAL POLIFONICA DE PIEDRAHITA ',
#  'CANTO EL CASTREJON-LAS FUENTES ',
# ...

# %%
listanegra= ['catol','inclusi','termic','fiest','tituliero','gala','polifon','suzuk','ginec','autom','athlet','zapater',
            'forest','residenc','aficio','billar','cebre','hadas','banco','campes','abuso','cofrad','natei','viviend','plaza',
            'catedr','matavie','solter','cocin','ambient','cepa','raza','etnog']

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 4427
# ['ASOCIACION FILATELICA AFILA ',
#  'ATOBAL',
#  'EL PIORNAL',
#  'LA TARASCA ',
#  'JIMENA BLAZQUEZ ',
#  'MOLINOS DE VIENTO ',
#  'ANDALUCIA DE AVILA ',
#  'DIEGO DE BRACAMONTE ',
#  'AL PIE DE LOS ALABES ',
#  'COMPARSA HARMONIA',
#  'LA JARKA ',
#  'ALAMEDA ',
#  'AMIGOS DE LA PARRA',
#  'ASOCIACION PRO-DEFENSA DE EL TREMEDAL ',
#  'LAS MORILLAS ',
#  'LAS NIEVES ',
#  'EL BUITRE GYPS FULVUS ',
#  'GUIA DE AVILA ',
#  'LA FUNDACION ',
#  'ASOCIACION LA ESTRELLA ',
#  'BEATRIZ DE SUABIA ',
#  'EL TOSTADO ',
#  'CARDIEL ',
#  'ADAJA ',
#  'PE A LOS TITULILLEROS ',
#  'ASOCIACION -LA TROMPETA ',
#  'ASOCIACION AMARI GOLE',
#  'AUTO CLASS OCHO DE AVILA ',
#  'CANTO EL CASTREJON-LAS FUENTES ',
#  'ASOCIACION -PE!A LA RESACA ',
#  'VILLA DEL ALBERCHE ',
#  'LA MANQUITA.',
#  'REINA SOFIA. ',
#  'AULA HORIZONTE ',
#  'CABEZO PICOTA ',
#  'ASOCIACION EL HASTIAL',
#  ' EL CAUCE ',
#  'EL CHARCO DEL CURA ',
#  'LA MANIVELA ',
#  'LA PEGUERA BAJA ',
#  'LUIGI BOCCHERINI DE AVILA ',
# ...

# %%
canin= extraer_por_palabra(df,'canin')
canin
# Out:
#           Num_Asoc      Ambito  \
# 364   09/1/0000991  AUTONOMICO
# 1087  09/1/0005530       LOCAL
# 1186  24/1/0000590  PROVINCIAL
# 1229  24/1/0001210  PROVINCIAL
# 1847  24/1/0005255  PROVINCIAL
# 2055  24/1/0006015       LOCAL
# 2075  24/1/0006083  PROVINCIAL
# 2950  37/1/0004286  PROVINCIAL
# 2953  37/1/0004300  PROVINCIAL
# 3512  40/1/0003377       LOCAL
# 3824  42/1/0002307       LOCAL
# 4302  47/1/0003929  AUTONOMICO
# 4510  47/1/0005134  AUTONOMICO
# 4646  47/1/0005663  AUTONOMICO
# 4844  49/1/0000595  PROVINCIAL
#
#                                              Asociación  Nif  \
# 364                 ASOCIACION CANINA BURGALESA-SORIANA  NaN
# 1087                     ASOCIACION CANINA VOM ZUGVOGEL  NaN
# 1186                 ASOCIACIÓN CANINA DE LEÓN (SOCALE)  NaN
# 1229                          ASOCIACIÓN CANINA LEONESA  NaN
# 1847                        ASOCIACIÓN CANINA CAN-DAMIA  NaN
# 2055                             ASOCIACIÓN CANINA C.K9  NaN
# ...

# %%
df_ok = pd.concat([df_ok , canin], axis=0)

# %%
df= restar_df(df, canin)

# %%
listanegra= ['maragata','castrillo','orgatillas','francia','cagatinajas','brigata','fogatos','cigatronic']

# %%
gat= extraer_por_palabra(df,'gat')
gat
# Out:
#           Num_Asoc      Ambito  \
# 59    05/1/0000755  PROVINCIAL
# 284   05/1/0002789  PROVINCIAL
# 1682  24/1/0004530  PROVINCIAL
# 1908  24/1/0005542  PROVINCIAL
# 1949  24/1/0005692  PROVINCIAL
# 2207  34/1/0001154  PROVINCIAL
# 2958  37/1/0004315  PROVINCIAL
# 2995  37/1/0004483  PROVINCIAL
# 3108  37/1/0004933  AUTONOMICO
# 3615  42/1/0000882  PROVINCIAL
# 3771  42/1/0002062       LOCAL
# 3948  47/1/0001087  PROVINCIAL
# 4227  47/1/0003488       LOCAL
# 4579  47/1/0005395       LOCAL
# 4691  47/1/0005862       LOCAL
# 4706  47/1/0005903       LOCAL
# 4709  47/1/0005924       LOCAL
#
#                                              Asociación        Nif  \
# 59                                       PE!A -EL GATO         NaN
# 284                                ASOCIACION MAMA GATA        NaN
# 1682                       ASOCIACIÓN LA RECUA MARAGATA        NaN
# 1908                       ASOCIACIÓN O SORRISO DO GATO        NaN
# ...

# %%
df_ok = pd.concat([df_ok , gat], axis=0)

# %%
df= restar_df(df, gat)
# Out:
# C:\Users\USUARIO\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)

# %%
perr= extraer_por_palabra(df,'perr')
perr
# Out:
#           Num_Asoc      Ambito  \
# 1111  09/1/0005601  PROVINCIAL
# 1723  24/1/0004670  PROVINCIAL
# 1775  24/1/0004958  PROVINCIAL
# 2308  34/1/0002156       LOCAL
# 2630  37/1/0001740    COMARCAL
# 2635  37/1/0001816  PROVINCIAL
# 2702  37/1/0002374  AUTONOMICO
# 2833  37/1/0003725  PROVINCIAL
# 2960  37/1/0004322  AUTONOMICO
# 3433  40/1/0002998  PROVINCIAL
# 4127  47/1/0002439  AUTONOMICO
# 4449  47/1/0004868       LOCAL
# 4991  49/1/0002477       LOCAL
#
#                                              Asociación  Nif  \
# 1111                       ASOCIACION PERRUNNERS BURGOS  NaN
# 1723                         ASOCIACIÓN PERRUNA DE LEÓN  NaN
# 1775                         ASOCIACIÓN EL PERRO BLANCO  NaN
# 2308                   ASOCIACION DE PERRERAS DE GUARDO  NaN
# 2630        ASOCIACION MIROBRIGENSE DE AMIGOS DEL PERRO  NaN
# 2635                CAN ASOCIACION EN DEFENSA DEL PERRO  NaN
# 2702       ASOCIACION DEFENSA DE LOS DERECHOS DEL PERRO  NaN
# ...

# %%
df_ok = pd.concat([df_ok , perr], axis=0)

# %%
df= restar_df(df, perr)
# Out:
# C:\Users\USUARIO\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)

# %%
colmill= extraer_por_palabra(df,'colmill')
colmill
# Out:
#          Num_Asoc      Ambito                      Asociación  Nif  \
# 363  09/1/0000982  PROVINCIAL  ASOCIACION EL COLMILLO, DE OÑA  NaN
#
#        Domicilio Municipio Provincia C_Postal  Web Fines Fines_Específicos  \
# 363  Del Pan nº2       OÑA    BURGOS     9000  NaN   NaN               NaN
#
#               F_Registro Unnamed: 12
# 363  1987-02-26 00:00:00         NaT

# %%
df_ok = pd.concat([df_ok , colmill], axis=0)

# %%
df= restar_df(df, colmill)

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 4413
# ['ASOCIACION FILATELICA AFILA ',
#  'ATOBAL',
#  'EL PIORNAL',
#  'LA TARASCA ',
#  'JIMENA BLAZQUEZ ',
#  'MOLINOS DE VIENTO ',
#  'ANDALUCIA DE AVILA ',
#  'DIEGO DE BRACAMONTE ',
#  'AL PIE DE LOS ALABES ',
#  'COMPARSA HARMONIA',
#  'LA JARKA ',
#  'ALAMEDA ',
#  'AMIGOS DE LA PARRA',
#  'ASOCIACION PRO-DEFENSA DE EL TREMEDAL ',
#  'LAS MORILLAS ',
#  'LAS NIEVES ',
#  'EL BUITRE GYPS FULVUS ',
#  'GUIA DE AVILA ',
#  'LA FUNDACION ',
#  'ASOCIACION LA ESTRELLA ',
#  'BEATRIZ DE SUABIA ',
#  'EL TOSTADO ',
#  'CARDIEL ',
#  'ADAJA ',
#  'PE A LOS TITULILLEROS ',
#  'ASOCIACION -LA TROMPETA ',
#  'ASOCIACION AMARI GOLE',
#  'AUTO CLASS OCHO DE AVILA ',
#  'CANTO EL CASTREJON-LAS FUENTES ',
#  'ASOCIACION -PE!A LA RESACA ',
#  'VILLA DEL ALBERCHE ',
#  'LA MANQUITA.',
#  'REINA SOFIA. ',
#  'AULA HORIZONTE ',
#  'CABEZO PICOTA ',
#  'ASOCIACION EL HASTIAL',
#  ' EL CAUCE ',
#  'EL CHARCO DEL CURA ',
#  'LA MANIVELA ',
#  'LA PEGUERA BAJA ',
#  'LUIGI BOCCHERINI DE AVILA ',
# ...

# %%
listanegra= ['compar','paso','olimpi','panel','consej','uni','comet','verde','crim','jard','afric','racing','horno',
            'happy','eki','coraz','green','tente','trio','comun','venezue','tranka','cruce','presa','merca','rol burgos',
            'niev','molin','guia','funda','adaj','fil','auto','reina','manq','manive','cauc','fall','buki','atob',
            'alame','estrella','tost','card','titu','trom','vill','avila viv','acude','rincon','march','teja','pedro',
            'tiemblo','ñapa','veton','charcue','respir','kuidi','viking','luna','integr','lomi','niñ','enred','cupcak',
            'movem','tres','ads','regio','hospi','muert','pasieg','cid','empecin','monte','sasam','salter','jazz',
            'canto','cabez','andaluc','piorn','pie','jark','taras','mor','amari','gyps','todoss','furgo','gente','cova',
            'autu','aratr','lanch','hoyo','amble','aero','atuva','adaner','amble','altoza','narros','ave','train','digita',
             'come','amigo burg','seño','andaluc','laring','foco','cuco','siglo','bar','doble','salega','proal','mahog','antigu',
             'hij','abym','pajar','north','volar','regga','aranda','serendip','revoluc','marqu','jime','sopl','umbri','cura',
            'aula','beat','luig','peguer','bonsai','resaca','parra','monumen','carret','vibore','asortis','pataform','puente',
            'herven','bird','voces','corta','olmo','conviv','coral','ceboll','asorid','migra','exis','mascarada','mascarpone',
            'hechic']

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 3230
# ['ASOCIACION EL HASTIAL',
#  'ASOCIACION ABULENSE DE HERALDICA Y GENEALOGIA ',
#  'ASOCIACION EL ARRABAL',
#  'ASOCIACION -SIVANANDA ',
#  'ASOCIACION -LOS SERENOS-',
#  'ASOCIACION -ALDEMA ',
#  'ASOCIACION -EL ADOQUIN ',
#  'PE!A AZULGRANA JOHAN CRUYFF',
#  'ASOCIACION -VERTICALIA ',
#  'ASOCIACION LOS CHABUCOS ',
#  'ASOCIACION EL VALLE',
#  'ASOCIACION EL REGAJILLO',
#  'ASOCIACION LA TRUHANA',
#  'ASOCIACION AMIGOS DE HIGUERA',
#  'ASOCIACION CEFAS',
#  'ASOCIACION CARASUR',
#  'ASOCIACION AIRES DEL ARAVALLE',
#  'ASOCIACION AMIGAS DE MONSALUPE',
#  'ASOCIACION LA SERRADILLA',
#  'ASOCIACION FORO CIVICO DE AVILA',
#  'ASOCIACION DE AMIGOS DEL CAÑEO EL CHATEO Y EL TAPEO',
#  'ASOCIACION DE INTERNAUTAS ABULENSE',
#  'ASOCIACION LOS SEIS ROELES',
#  'ASOCIACION EXPEDICION SOLIDARIA',
#  'ASOCIACION DE AMIGOS DEL ARBITRAJE DE AVILA',
#  'ASOCIACION ALOJA',
#  'ASOCIACION EL TIENTO',
#  'ASOCIACION LUZ DE NARRILLOS',
#  'ASOCIACION VAHE',
#  'ASOCIACION KALATHOS',
# ...

# %%
defen= extraer_por_palabra(df,'defen')
list(defen['Asociación'].unique())
# Out:
# ['ASOCIACION PRO-DEFENSA DE EL TREMEDAL ',
#  'ASOCIACION EN DEFENSA DEL RIO ALBERCHE',
#  'ASOCIACION PLATAFORMA PARA LA DEFENSA DEL VALLE AMBLÉS',
#  'ASOCIACION PARA LA DEFENSA DE LOS DERECHOS DE LOS NO CREYENTES ANOCRE',
#  'COORDINADORA PARA LA DEFENSA DE LA CUENCA BAJA DEL RIO ARLANZON, DE PAMPLIEGA',
#  'ASOCIACION DEFENSA DEL MEDIO DE PALACIOS DE LA SIERRA  (ADEMPA)',
#  'ASOCIACION EN DEFENSA DEL RIO CERNEJA',
#  'ASOCIACIÓN COORDINADORA FABERENSE PARA LA DEFENSA DE LA CUENCA FABERO',
#  'ASOCIACIÓN COORDINADORA BÁRCENA DE LA ABADIA EN DEFENSA DEL RÍO CUA BÁRCENA DE LA ABADÍA',
#  'ASOCIACIÓN EN DEFENSA DEL PARADO DE LEÓN (ADEPALEÓN)',
#  'ASOCIACIÓN PLATAFORMA PARA LA DEFENSA DE GISTREO',
#  'ASOCIACION EN DEFENSA DE LA VIDA ADEVIDA',
#  'ASOCIACION CASTELLANO LEONESA PARA LA DEFENSA DEL MENOR (A.C.L.E.D.E.M.)',
#  'ASOCIACION PARA LA DEFENSA DE LAS AFECTADAS POR ESSURE (ADAE)',
#  'ASOCIACION DE DEFENSA DE TENZUELA ',
# ...

# %%
# df_ok = pd.concat([df_ok , ], axis=0)
df= restar_df(df, defen)

# %%
front= extraer_por_palabra(df,'front')
list(front['Asociación'].unique())
# Out:
# ['SIN FRONTERAS ',
#  'ASOCIACION FRONTENIS MEDINA DE POMAR',
#  'CRISTIANOS SIN FRONTERAS, DE BURGOS',
#  'SIN FRONTERAS',
#  'ASOCIACION BIOLOGOS SIN FRONTERAS',
#  'ASOCIACION FRONTENIS BOECILLO']

# %%
df= restar_df(df, front)

# %%
centro= extraer_por_palabra(df,'centro')
list(centro['Asociación'].unique())
# Out:
# ['CENTRO SEGOVIANO',
#  'CENTRO HOLISTICO',
#  'PLATAFORMA POR EL CENTRO LOGISTICO, DE MIRANDA DE EBRO',
#  'ASOCIACION CENTRO SORIANO EN BURGOS',
#  'CENTRO ARGENTINO BURGALES',
#  'ASOCIACION CENTRO ANDALUZ EN BURGOS',
#  'ASOCIACION BURGOS CENTRO Y COMPAÑIA',
#  'ASOCIACION CENTRO DE ANALISIS, DEMOCRACIA Y SOBERANIA',
#  'ASOCIACION CENTRO LOYOLA BURGOS',
#  'ASOCIACIÓN CENTRO DE RECURSOS E INICIATIVAS LOCALES',
#  'ASOCIACIÓN CENTRO GALICIA EN PONFERRADA',
#  'ASOCIACIÓN CENTRO DE DÍA HOGAR LA VEGA-LEÓN',
#  'ASOCIACIÓN CENTRO DRAMÁTICO LEONÉS',
#  'CENTRO EL RECREO',
#  'CENTRO INTERPRETACION DE LA MINERIA ASOCIACION (CIMA)',
#  'CENTRO NUEVA VIDA',
#  'CENTRO DE INTERCAMBIOS DE IDIOMAS (CEMII)',
#  'ASOCIACION DE CENTROS VALLADOLID-SALAMANCA ACEVASA',
#  'ASOCIACION CENTRO DRAMATICO',
#  'ASOCIACION COVIC CENTRO DE ORIENTACION Y ASISTENCIA A LA VICTIMA',
#  'ASOCIACION CENTRO SALAMANCA',
#  'CENTRO DE FORMACION DE LENGUA DE SIGNOS',
#  'CENTRO SEGOVIA ',
# ...

# %%
df= restar_df(df, centro)

# %%
prote= extraer_por_palabra(df,'prote')
list(prote['Asociación'].unique())
# Out:
# ['A.P.A PROTEGE',
#  'ASOCIACIÓN PARA PROMOVER LA PROTECCIÓN DE LOS PALOMARES EN LA PROVINCIA DE LEÓN',
#  'ASOCIACIÓN PROVINCIAL DE PROTECCIÓN CIVIL DE LEÓN',
#  'ASOCIACION PROTEUS',
#  'ASOCIACION VALLISOLETANA DE PROTECCION DE AUTISTAS',
#  'ASOCIACION PROVINCIAL DE COLABORADORES DE PROTECCION CIVIL DE VALLADOLID']

# %%
df= restar_df(df, prote)

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 3235
# ['ASOCIACION EL HASTIAL',
#  'ASOCIACION ABULENSE DE HERALDICA Y GENEALOGIA ',
#  'ASOCIACION EL ARRABAL',
#  'ASOCIACION -SIVANANDA ',
#  'ASOCIACION -LOS SERENOS-',
#  'ASOCIACION -ALDEMA ',
#  'ASOCIACION -EL ADOQUIN ',
#  'PE!A AZULGRANA JOHAN CRUYFF',
#  'ASOCIACION -VERTICALIA ',
#  'ASOCIACION LOS CHABUCOS ',
#  'ASOCIACION EL VALLE',
#  'ASOCIACION EL REGAJILLO',
#  'ASOCIACION LA TRUHANA',
#  'ASOCIACION AMIGOS DE HIGUERA',
#  'ASOCIACION CEFAS',
#  'ASOCIACION CARASUR',
#  'ASOCIACION AIRES DEL ARAVALLE',
#  'ASOCIACION AMIGAS DE MONSALUPE',
#  'ASOCIACION LA SERRADILLA',
#  'ASOCIACION FORO CIVICO DE AVILA',
#  'ASOCIACION DE AMIGOS DEL CAÑEO EL CHATEO Y EL TAPEO',
#  'ASOCIACION DE INTERNAUTAS ABULENSE',
#  'ASOCIACION LOS SEIS ROELES',
#  'ASOCIACION EXPEDICION SOLIDARIA',
#  'ASOCIACION DE AMIGOS DEL ARBITRAJE DE AVILA',
#  'ASOCIACION ALOJA',
#  'ASOCIACION EL TIENTO',
#  'ASOCIACION LUZ DE NARRILLOS',
#  'ASOCIACION VAHE',
#  'ASOCIACION KALATHOS',
# ...

# %%
masc= extraer_por_palabra(df,'masc')
list(masc['Asociación'].unique())
# Out:
# ['ASOCIACIÓN DE AMIGOS DE LAS MASCOTAS', 'ASOCIACIÓN EXPOMASCOT']

# %%
df_ok = pd.concat([df_ok , masc], axis=0)
df= restar_df(df,masc)

# %%
pelud= extraer_por_palabra(df,'pelud')
list(pelud['Asociación'].unique())
# Out:
# ['ASOCIACION LOS PELUDOS',
#  'ASOCIACION AMIGO PELUDO',
#  'ASOCIACION TODO POR LOS PELUD@S']

# %%
df_ok = pd.concat([df_ok , pelud], axis=0)
df= restar_df(df,pelud)

# %%
amig= extraer_por_palabra(df,'amig')
print(len(list(amig['Asociación'].unique())))
list(amig['Asociación'].unique())
# Out:
# 283
# ['ASOCIACION AMIGOS DE HIGUERA',
#  'ASOCIACION AMIGAS DE MONSALUPE',
#  'ASOCIACION DE AMIGOS DEL CAÑEO EL CHATEO Y EL TAPEO',
#  'ASOCIACION DE AMIGOS DEL ARBITRAJE DE AVILA',
#  'ASOCIACION AMIGOS DE LA DEHESA DE SOTILLO DE LA ADRADA',
#  'ASOCIACION AMIGOS DE LA ERMITA DEL SOTO',
#  'AMIGOS DEL RETABLO DE LA HERGUIJUELA',
#  'AMIGOS VETTONES',
#  'AMIGOS NARRILLOS DEL ALAMO, (A.N.D.A)',
#  'ASOCIACION AMIGOS MTB MAELLO',
#  'ASOCIACION AMIGOS DE EL MIRON DE AVILA',
#  'AMIGOS DEL ARLANZA',
#  'AMIGOS DE LA ALTA SIERRA',
#  'ASOCIACION AMIGOS DE FRIAS',
#  'ASOCIACION DE AMIGOS DEL LAGO AZUL',
#  'ASOCIACION DE AMIGOS DE POZA DE LA SAL',
#  'ASOCIACION DE AMIGOS DEL ARBITRAJE',
#  'ASOCIACION AMIGOS DE HACINAS',
#  'ASOCIACION AMIGOS DE MAZUELA',
#  'ASOCIACION DE AMIGOS DE MEDINA DE POMAR',
#  'ASOCIACION DE AMIGOS DE SILANES',
#  'ASOCIACION AMIGOS DE TUDANCA DE EBRO',
#  'ASOCIACION AMIGOS DE BELORADO',
#  'ASOCIACION AMIGOS DE AGÜERA',
# ...

# %%
df= restar_df(df,amig)

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 2944
# ['ASOCIACION EL HASTIAL',
#  'ASOCIACION ABULENSE DE HERALDICA Y GENEALOGIA ',
#  'ASOCIACION EL ARRABAL',
#  'ASOCIACION -SIVANANDA ',
#  'ASOCIACION -LOS SERENOS-',
#  'ASOCIACION -ALDEMA ',
#  'ASOCIACION -EL ADOQUIN ',
#  'PE!A AZULGRANA JOHAN CRUYFF',
#  'ASOCIACION -VERTICALIA ',
#  'ASOCIACION LOS CHABUCOS ',
#  'ASOCIACION EL VALLE',
#  'ASOCIACION EL REGAJILLO',
#  'ASOCIACION LA TRUHANA',
#  'ASOCIACION CEFAS',
#  'ASOCIACION CARASUR',
#  'ASOCIACION AIRES DEL ARAVALLE',
#  'ASOCIACION LA SERRADILLA',
#  'ASOCIACION FORO CIVICO DE AVILA',
#  'ASOCIACION DE INTERNAUTAS ABULENSE',
#  'ASOCIACION LOS SEIS ROELES',
#  'ASOCIACION EXPEDICION SOLIDARIA',
#  'ASOCIACION ALOJA',
#  'ASOCIACION EL TIENTO',
#  'ASOCIACION LUZ DE NARRILLOS',
#  'ASOCIACION VAHE',
#  'ASOCIACION KALATHOS',
#  'ASOCIACION DEHESA GALINGOMEZ',
#  'ASOCIACION LA ARBOLEDA DE SALOBRAL',
#  'ASOCIACION EL SILO DE ARENAS',
#  'ASOCIACION RED ARRAYAN AVILA',
#  'ASOCIACION ESPITA GORGORITA',
# ...

# %%
listanegra= ['orgull','teso','pe!','viva','romá','world','borea','fris','mueve','yema','scena','aten','celos',
             'ainur']

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 2889
# ['ASOCIACION EL HASTIAL',
#  'ASOCIACION ABULENSE DE HERALDICA Y GENEALOGIA ',
#  'ASOCIACION EL ARRABAL',
#  'ASOCIACION -SIVANANDA ',
#  'ASOCIACION -LOS SERENOS-',
#  'ASOCIACION -ALDEMA ',
#  'ASOCIACION -EL ADOQUIN ',
#  'ASOCIACION -VERTICALIA ',
#  'ASOCIACION LOS CHABUCOS ',
#  'ASOCIACION EL VALLE',
#  'ASOCIACION EL REGAJILLO',
#  'ASOCIACION LA TRUHANA',
#  'ASOCIACION CEFAS',
#  'ASOCIACION CARASUR',
#  'ASOCIACION AIRES DEL ARAVALLE',
#  'ASOCIACION LA SERRADILLA',
#  'ASOCIACION FORO CIVICO DE AVILA',
#  'ASOCIACION DE INTERNAUTAS ABULENSE',
#  'ASOCIACION LOS SEIS ROELES',
#  'ASOCIACION EXPEDICION SOLIDARIA',
#  'ASOCIACION ALOJA',
#  'ASOCIACION EL TIENTO',
#  'ASOCIACION LUZ DE NARRILLOS',
#  'ASOCIACION VAHE',
#  'ASOCIACION KALATHOS',
#  'ASOCIACION DEHESA GALINGOMEZ',
#  'ASOCIACION LA ARBOLEDA DE SALOBRAL',
#  'ASOCIACION EL SILO DE ARENAS',
#  'ASOCIACION RED ARRAYAN AVILA',
#  'ASOCIACION ESPITA GORGORITA',
#  'ASOCIACION HEKATON',
# ...

# %%
aso= extraer_por_palabra(df,'aso')
print(len(list(aso['Asociación'].unique())))
list(aso['Asociación'].unique())
# Out:
# 2402
# ['ASOCIACION EL HASTIAL',
#  'ASOCIACION ABULENSE DE HERALDICA Y GENEALOGIA ',
#  'ASOCIACION EL ARRABAL',
#  'ASOCIACION -SIVANANDA ',
#  'ASOCIACION -LOS SERENOS-',
#  'ASOCIACION -ALDEMA ',
#  'ASOCIACION -EL ADOQUIN ',
#  'ASOCIACION -VERTICALIA ',
#  'ASOCIACION LOS CHABUCOS ',
#  'ASOCIACION EL VALLE',
#  'ASOCIACION EL REGAJILLO',
#  'ASOCIACION LA TRUHANA',
#  'ASOCIACION CEFAS',
#  'ASOCIACION CARASUR',
#  'ASOCIACION AIRES DEL ARAVALLE',
#  'ASOCIACION LA SERRADILLA',
#  'ASOCIACION FORO CIVICO DE AVILA',
#  'ASOCIACION DE INTERNAUTAS ABULENSE',
#  'ASOCIACION LOS SEIS ROELES',
#  'ASOCIACION EXPEDICION SOLIDARIA',
#  'ASOCIACION ALOJA',
#  'ASOCIACION EL TIENTO',
#  'ASOCIACION LUZ DE NARRILLOS',
#  'ASOCIACION VAHE',
#  'ASOCIACION KALATHOS',
#  'ASOCIACION DEHESA GALINGOMEZ',
#  'ASOCIACION LA ARBOLEDA DE SALOBRAL',
#  'ASOCIACION EL SILO DE ARENAS',
#  'ASOCIACION RED ARRAYAN AVILA',
#  'ASOCIACION ESPITA GORGORITA',
#  'ASOCIACION HEKATON',
# ...

# %%
df= restar_df(df,aso)

# %%
print(len(list(df['Asociación'].unique())))
list(df['Asociación'].unique())
# Out:
# 487
# ['PLATAFORMA SOS REAL AVILA',
#  'ESPLENDOR DEL VALLE',
#  'COORDINADORA CONTRA EL PARO DE BURGOS Y COMARCA, DE BURGOS',
#  'ARRENDATARIOS CALLE RAMON Y CAJAL Nº 2',
#  'ASHEF RECUPERAMOS LA  ENGAÑA',
#  'PLATAFORMA BLANCA DE AFECTADOS DE LEON',
#  'PLATAFORMA CONTRA LA LINEA DE ALTA TENSIÓN LA TERCIA Y ARBAS',
#  'EL COTIGON',
#  'ALDEVE',
#  'LACIANA CON LOS CINCO SENTIDOS',
#  'VIMACYL',
#  'PAISAJES Y VIÑEDOS DEL BIERZO',
#  'AMAR Y MAMAR',
#  'KREATIVA CLASSIC',
#  'JAVI KIZOMBA FUSIÓN',
#  'EL CARCABÓN',
#  'BIERZO RENOVABLE',
#  'BIERZO GARANTÍA',
#  'AECIP CYL',
#  'LA FACENDERA DE VALDEVIMBRE',
#  'SOMOS UCRANIA',
#  'SALVEMOS EL PELGO',
#  'LA CUEVA DEL BALROG',
#  'LEÓN PROPONE',
#  'LOS HUERTOS AL SOL',
#  'SENTIMIENTO BERCIANO',
#  'APA RALLY TEAM',
#  'ANHERON',
#  'LA CHOMBINA',
#  'PROPULSIÓN',
#  'THE EMERALD LION',
#  'MIRADA AL BIERZO',
#  'EL MÉTODO',
#  'BABY BOOMERS',
#  'AM MEZZOFORTE SOUND MACHINE',
#  'TRIBU AMBACTOS',
# ...

# %% [markdown]
# Ya no me interesa df, me centro en aso:

# %%
print(len(list(aso['Asociación'].unique())))
list(aso['Asociación'].unique())
# Out:
# 2402
# ['ASOCIACION EL HASTIAL',
#  'ASOCIACION ABULENSE DE HERALDICA Y GENEALOGIA ',
#  'ASOCIACION EL ARRABAL',
#  'ASOCIACION -SIVANANDA ',
#  'ASOCIACION -LOS SERENOS-',
#  'ASOCIACION -ALDEMA ',
#  'ASOCIACION -EL ADOQUIN ',
#  'ASOCIACION -VERTICALIA ',
#  'ASOCIACION LOS CHABUCOS ',
#  'ASOCIACION EL VALLE',
#  'ASOCIACION EL REGAJILLO',
#  'ASOCIACION LA TRUHANA',
#  'ASOCIACION CEFAS',
#  'ASOCIACION CARASUR',
#  'ASOCIACION AIRES DEL ARAVALLE',
#  'ASOCIACION LA SERRADILLA',
#  'ASOCIACION FORO CIVICO DE AVILA',
#  'ASOCIACION DE INTERNAUTAS ABULENSE',
#  'ASOCIACION LOS SEIS ROELES',
#  'ASOCIACION EXPEDICION SOLIDARIA',
#  'ASOCIACION ALOJA',
#  'ASOCIACION EL TIENTO',
#  'ASOCIACION LUZ DE NARRILLOS',
#  'ASOCIACION VAHE',
#  'ASOCIACION KALATHOS',
#  'ASOCIACION DEHESA GALINGOMEZ',
#  'ASOCIACION LA ARBOLEDA DE SALOBRAL',
#  'ASOCIACION EL SILO DE ARENAS',
#  'ASOCIACION RED ARRAYAN AVILA',
#  'ASOCIACION ESPITA GORGORITA',
#  'ASOCIACION HEKATON',
# ...

# %%
para= extraer_por_palabra(aso,'para')
list(para['Asociación'].unique())
# Out:
# ['ASOCIACION PARA REVITALIZAR PASARILLA',
#  'ASOCIACION PARA LA REPOBLACION DE LOS BOSQUES INCENDIADOS DE EL ARENAL ARBIA',
#  'ASOCIACION PARA EL FOMENTO DEL APRENDIZAJE A LO LARGO DE LA VIDA (AFALVI)',
#  'ASOCIACION PARA LA RECUPERACION DE LA COMARCA DEL EBRO (A.R.C.E.)',
#  'ASOCIACION PARA LA FORMACION Y REINSERCION LABORAL, DE BURGOS',
#  'ASOCIACION AMEPAX (ASOCIACION DE MEDIACION PARA LA PACIFICACION DE CONFLICTOS DE BURGOS)',
#  'ASOCIACION +PARAFERNALIA',
#  'ASOCIACIÓN RE & RE PARAMO DE MASA',
#  'ASOCIACIÓN LA INSTRUCTIVA PARAMESA',
#  'ASOCIACIÓN PARA EL ARREGLO DE LA IGLESIA PALACIOS DE LA VALDUERNA',
#  'ASOCIACIÓN PARA LA PROMOCIÓN DE LA CECINA DE CHIVO DE VEGACERVERA',
#  'ASOCIACIÓN PARA LA PROMOCIÓN Y FOMENTO DEL PUERRO DE SAHAGÚN',
#  'ASOCIACIÓN LEONESA DE PARADOS 2.000 (ALEPA 2.000)',
#  'ASOCIACIÓN PARA LA PROMOCIÓN DEL CHORIZO DE LEÓN',
#  'ASOCIACIÓN PARA LA FORMACIÓN CLARÍN',
#  'ASOCIACIÓN LEONESA DE PARAGUAY',
#  'ASOCIACIÓN PARADA 13',
# ...

# %%
aso= restar_df(aso,para)

# %%
print(len(list(aso['Asociación'].unique())))
list(aso['Asociación'].unique())
# Out:
# 2356
# ['ASOCIACION EL HASTIAL',
#  'ASOCIACION ABULENSE DE HERALDICA Y GENEALOGIA ',
#  'ASOCIACION EL ARRABAL',
#  'ASOCIACION -SIVANANDA ',
#  'ASOCIACION -LOS SERENOS-',
#  'ASOCIACION -ALDEMA ',
#  'ASOCIACION -EL ADOQUIN ',
#  'ASOCIACION -VERTICALIA ',
#  'ASOCIACION LOS CHABUCOS ',
#  'ASOCIACION EL VALLE',
#  'ASOCIACION EL REGAJILLO',
#  'ASOCIACION LA TRUHANA',
#  'ASOCIACION CEFAS',
#  'ASOCIACION CARASUR',
#  'ASOCIACION AIRES DEL ARAVALLE',
#  'ASOCIACION LA SERRADILLA',
#  'ASOCIACION FORO CIVICO DE AVILA',
#  'ASOCIACION DE INTERNAUTAS ABULENSE',
#  'ASOCIACION LOS SEIS ROELES',
#  'ASOCIACION EXPEDICION SOLIDARIA',
#  'ASOCIACION ALOJA',
#  'ASOCIACION EL TIENTO',
#  'ASOCIACION LUZ DE NARRILLOS',
#  'ASOCIACION VAHE',
#  'ASOCIACION KALATHOS',
#  'ASOCIACION DEHESA GALINGOMEZ',
#  'ASOCIACION LA ARBOLEDA DE SALOBRAL',
#  'ASOCIACION EL SILO DE ARENAS',
#  'ASOCIACION RED ARRAYAN AVILA',
#  'ASOCIACION ESPITA GORGORITA',
#  'ASOCIACION HEKATON',
# ...

# %%
abul= extraer_por_palabra(aso,'abul')
list(abul['Asociación'].unique())
# Out:
# ['ASOCIACION ABULENSE DE HERALDICA Y GENEALOGIA ',
#  'ASOCIACION DE INTERNAUTAS ABULENSE',
#  'ASOCIACION DARDERA ABULENSE',
#  'ASOCIACION ABULENSE DE AFECTADOS POR LAS PREFERENTES Y SUBORDINADAS',
#  'ASOCIACION ABULENSE DE ASISTENCIA A VICTIMAS DE VIOLENCIA DE GENERO AVIVIG',
#  'ASOCIACION ABULENSE DE OSTOMIZADOS (ASABO)',
#  'ASOCIACION ABULA FEYMA']

# %%
aso= restar_df(aso,abul)

# %%
avi= extraer_por_palabra(aso,'avi')
list(avi['Asociación'].unique())
# Out:
# ['ASOCIACION FORO CIVICO DE AVILA',
#  'ASOCIACION RED ARRAYAN AVILA',
#  'ASOCIACION NILAYA AVILA',
#  'ASOCIACION DE ILUSIONISTAS DE AVILA',
#  'ASOCIACION DE TRABAJADORAS Y TRABAJADORES DE HOGAR DE AVILA ATHA',
#  'ASOCIACION AVILA ABIERTA',
#  'ASOCIACION DE GOURMETS DE AVILA',
#  'PRENSAVILA ASOCIACION',
#  'ASOCIACION CAMPERAVILA',
#  'ASOCIACION EL RECRE 14 AVILA',
#  'ASOCIACION LOS GIGANTONES DE AVILA',
#  'FEDERACION DE ASOCIACIONES SIN ANIMO DE LUCRO DE AVILA',
#  'ASOCIACION LA AVIONETA',
#  'ASOCIACION COMAVI',
#  'ASOCIACIÓN AYUDA A LAS REPÚBLICAS DE LA EXTINTA YUGOSLAVIA EN PONFERRADA',
#  'ASOCIACIÓN INTERAMNIUM FLAVIUM',
#  'ASOCIACION BUENAVISTA DE GRIJOTA',
#  'ASOCIACION BUENAVISTA 16',
#  'ASOCIACION PALENTINA DE AYUDA A VICTIMAS DEL ACOSO (ASOCIACION PAVIA)',
#  'ASOCIACION HOLAVITA',
#  'ASOCIACION SLAVIANIE EUROPA',
#  'ASOCIACION NAVIAS',
#  'ASOCIACIÓN PILOTO DE AVIONETA',
#  'ASOCIACION ARAVIANA DE NOVIERCAS',
#  'ASOCIACION LA COLODRA DE AÑAVIEJA',
# ...

# %%
aso= restar_df(aso,avi)

# %%
leon= extraer_por_palabra(aso,'leon')
list(leon['Asociación'].unique())
# Out:
# ['ASOCIACION CASTELLANO-LEONESA DE PAINTBALL',
#  'ASOCIACIÓN CATÓLICA DE MAESTROS LEONESES',
#  'ASOCIACIÓN ORFEÓN LEONÉS',
#  'ASOCIACIÓN FOCUS DE FOTÓGRAFOS LEONESES',
#  'ASOCIACIÓN BELENISTA LEONESA',
#  'ASOCIACIÓN DE VITRALISTAS LEONESES ASVIL',
#  'ASOCIACIÓN ACOGEDORES LEONESES ESPECIALIZADOS (A.L.E.)',
#  'ASOCIACIÓN XEITU BABLE-LLEON',
#  'ASOCIACIÓN FACENDERA POLA LLINGUA.CONCEYU DE FALANTES DE LLEONÉS',
#  'ASOCIACIÓN LEONESA DE DAÑO CEREBRAL SOBREVENIDO ALEN',
#  'ASOCIACIÓN PROLEONVER',
#  'ASOCIACIÓN COLONIA CUBANO-LEONESA',
#  'ASOCIACIÓN LEONESA DE URGENCIAS Y EMERGENCIAS',
#  'ASOCIACIÓN ONDAS LEONESAS',
#  'ASOCIACIÓN LEONESA DE SLOT',
#  'ASOCIACION CASTELLANO-LEONESA DE NEUROCIRUGÍA',
#  'ASOCIACIÓN LEONESA DE ÁRBITROS DE BALONCESTO',
#  'ASOCIACIÓN LEONESA DE AFECTADOS POR EXPROPIACIONES -A.L.A.E.-',
#  'ASOCIACIÓN LEONESA SUPERAR LA DISLEXIA',
#  'ASOCIACIÓN LEONESA CONTRA EL ACOSO LABORAL -ALACOLA-',
#  'ASOCIACIÓN LEONESA DE AIRSOFT',
# ...

# %%
aso= restar_df(aso,leon)

# %%
print(len(list(aso['Asociación'].unique())))
list(aso['Asociación'].unique())
# Out:
# 2264
# ['ASOCIACION EL HASTIAL',
#  'ASOCIACION EL ARRABAL',
#  'ASOCIACION -SIVANANDA ',
#  'ASOCIACION -LOS SERENOS-',
#  'ASOCIACION -ALDEMA ',
#  'ASOCIACION -EL ADOQUIN ',
#  'ASOCIACION -VERTICALIA ',
#  'ASOCIACION LOS CHABUCOS ',
#  'ASOCIACION EL VALLE',
#  'ASOCIACION EL REGAJILLO',
#  'ASOCIACION LA TRUHANA',
#  'ASOCIACION CEFAS',
#  'ASOCIACION CARASUR',
#  'ASOCIACION AIRES DEL ARAVALLE',
#  'ASOCIACION LA SERRADILLA',
#  'ASOCIACION LOS SEIS ROELES',
#  'ASOCIACION EXPEDICION SOLIDARIA',
#  'ASOCIACION ALOJA',
#  'ASOCIACION EL TIENTO',
#  'ASOCIACION LUZ DE NARRILLOS',
#  'ASOCIACION VAHE',
#  'ASOCIACION KALATHOS',
#  'ASOCIACION DEHESA GALINGOMEZ',
#  'ASOCIACION LA ARBOLEDA DE SALOBRAL',
#  'ASOCIACION EL SILO DE ARENAS',
#  'ASOCIACION ESPITA GORGORITA',
#  'ASOCIACION HEKATON',
#  'ASOCIACION PIMPOLLAR',
#  'ASOCIACION KUIDVIS',
#  'ASOCIACION CROSS ROAD',
#  'ASOCIACION LOS RAPEÑOS',
#  'ASOCIACION GEYCOR GESTION AGRARIA',
#  'ASOCIACION ALA VETTONUM',
# ...

# %%
leo_n= extraer_por_palabra(aso,'león')
list(leo_n['Asociación'].unique())
# Out:
# ['ASOCIACIÓN CAPILLA CLÁSICA DE LEÓN',
#  'ASOCIACIÓN CASA DE GALICIA EN LEÓN',
#  'ASOCIACIÓN ALIANZA FRANCESA DE LEÓN',
#  'ASOCIACIÓN AFECTADOS SÍNDROME TÓXICO DE LEÓN',
#  'ASOCIACIÓN INICIATIVA 87 DE LEÓN',
#  'ASOCIACIÓN 24 LEÓN',
#  'ASOCIACIÓN EN CAMINO DE LEÓN',
#  'ASOCIACIÓN LOS BOMBAS LEÓN',
#  'ASOCIACIÓN MOVIMIENTO DE RENOVACIÓN PEDAGÓGICA LEGIO XXI. LEÓN',
#  'ASOCIACIÓN DE AMISTAD CON CUBA DE LEÓN',
#  'ASOCIACIÓN VEGARADA LEÓN',
#  'ASOCIACIÓN HALACHA LEÓN',
#  'ASOCIACIÓN ACCIÓN PÚBLICA LEÓN',
#  'ASOCIACIÓN TIEMPOS OSCUROS LEÓN',
#  'ASOCIACIÓN CARACOL LEÓN',
#  'ASOCIACIÓN LIGA REUMATOLÓGICA LEÓN (LIRELEÓN)',
#  'ASOCIACIÓN CAMERATA LAURENTINA LEÓN',
#  'ASOCIACIÓN S.O.S. RACISMO DE LEÓN',
#  'ASOCIACIÓN BÚRBULA LEÓN',
#  'ASOCIACIÓN ENTREVÍAS LEÓN',
#  'ASOCIACIÓN LUCHA ANTIGRANIZO DE LEÓN',
#  'ASOCIACIÓN DE SUMILLERES DE LEÓN (A.S.L.E.)',
#  'ASOCIACIÓN VOLKSWAGEN CLÁSICO LEÓN',
#  'ASOCIACIÓN ZONA LEÓN',
#  'ASOCIACIÓN DE SOFTWARE LIBRE DE LEÓN (SLEÓN)',
# ...

# %%
df_ok
# Out:
#           Num_Asoc      Ambito  \
# 606   05/1/0000764       LOCAL
# 2075  05/1/0002393  PROVINCIAL
# 2085  05/1/0002403  PROVINCIAL
# 2218  05/1/0002543       LOCAL
# 2225  05/1/0002550  PROVINCIAL
# ...            ...         ...
# 951   24/1/0004579  PROVINCIAL
# 1095  24/1/0005408  PROVINCIAL
# 350   09/1/0004362       LOCAL
# 1362  34/1/0002259  PROVINCIAL
# 1376  34/1/0002467  PROVINCIAL
#
#                                              Asociación        Nif  \
# 606   ASOCIACION HUELLAS PROTECTORA DE ANIMALES DE A...  G05120217
# 2075        ASOCIACION PROTECTORA DE ANIMALES VILLAPEPA        NaN
# 2085  ASOCIACION DE TERAPIA ASISTIDA CON ANIMALES EQ...        NaN
# 2218       ASOCIACION PROTECTORA S.O.S ANIMAL LA ADRADA        NaN
# 2225  ASOCIACION PROTECTORA DE ANIMALES ANIMALES EN ...        NaN
# ...                                                 ...        ...
# 951                ASOCIACIÓN DE AMIGOS DE LAS MASCOTAS        NaN
# ...

# %%
# Guardar DataFrame en un archivo de Excel
df_ok.to_excel('asociaciones_castillaleon_filtrado.xlsx', index=False)
