# %%
import pandas as pd

# %%
df= pd.read_excel("C:/Users/USUARIO/TRABAJO DE FIN DE GRADO/CENTROS/1. DATOS EN CRUDO/asociaciones_canarias.xlsx")

# %%
df
# Out:
#            Nº CANARIO. C.I.F.  \
# 0      G1/S1/243-76/TF    NaN
# 1      G1/S1/873-83/TF    NaN
# 2      G1/S1/959-84/TF    NaN
# 3     G1/S1/1018-85/TF    NaN
# 4     G1/S1/1026-85/TF    NaN
# ..                 ...    ...
# 389  G1/S1/26236-23/TF    NaN
# 390  G1/S1/26243-23/GC    NaN
# 391  G1/S1/26256-23/GC    NaN
# 392  G1/S1/26258-23/TF    NaN
# 393  G1/S1/26293-23/GC    NaN
#
#                                           DENOMINACION      AMBITO  \
# 0               PADRES Y AMIGOS DEL SORDO (A.S.P.A.S.)  PROVINCIAL
# 1                         TINERFEñA AMIGOS DEL CABALLO  PROVINCIAL
# 2                                      CAN DE TENERIFE  PROVINCIAL
# 3    DEFENSA, PROTEC., MANTENIMIENTO Y MEJORA PAT. ...  PROVINCIAL
# 4                                             CAN CLUB  AUTONÓMICO
# ..                                                 ...         ...
# 389          ASOCIACIÓN BIENESTAR ANIMAL YCODEM (ABAY)  AUTONÓMICO
# 390                             DOGANDCAT PET´S LOVERS   MUNICIPAL
# 391  DE ADIESTRADORES CANINOS DE CANARIAS "GT.BOCAL...  AUTONÓMICO
# 392            FINCA CADA VIDA CUENTA BIENESTAR ANIMAL  AUTONÓMICO
# 393                          GUANCHE DEL PRESA CANARIO  AUTONÓMICO
#
#                       SECCION               ACTIVIDADES FECHA CONSTITUCIÓN  \
# 0    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         27/05/1976
# 1    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         30/09/1983
# 2    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         05/11/1984
# 3    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         26/07/1985
# 4    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         26/09/1985
# ..                        ...                       ...                ...
# 389  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         05/09/2022
# 390  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         30/10/2022
# 391  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         15/01/2023
# 392  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         16/10/2022
# 393  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         07/02/2023
#
#                                              DIRECCION  \
# 0               AVDA. LOS REYES CATOLICOS N.28-1 VDA.2
# 1                    CAMINO LA CORDILLERA, 2 - GUAMASA
# 2                                         C/ VIANA, 69
# 3                                  C/ HERMANO PEDRO, 9
# 4    RAMBLA GENERAL FRANCO, 135 BAJO - APTDO. CORRE...
# ..                                                 ...
# 389                     CALLE MAJUELO Nº 32 BUEN PASO
# 390         CARRETERA DE MATA, Nº 85, TRASERA, 2º PISO
# 391                             LGAR. AYAGAURES, Nº 10
# 392                            CALLE LOS COSTALES Nº4
# 393  C/ LETRADO RAMÍREZ DORESTE, Nº 2, PLANTA BAJA ...
#
#                   PROVINCIA          ISLA                   MUNICIPIO  \
# 0    Santa Cruz de Tenerife      TENERIFE      SANTA CRUZ DE TENERIFE
# 1    Santa Cruz de Tenerife      TENERIFE  SAN CRISTOBAL DE LA LAGUNA
# 2    Santa Cruz de Tenerife      TENERIFE  SAN CRISTOBAL DE LA LAGUNA
# 3    Santa Cruz de Tenerife      TENERIFE                    VILAFLOR
# 4    Santa Cruz de Tenerife      TENERIFE      SANTA CRUZ DE TENERIFE
# ..                      ...           ...                         ...
# 389  Santa Cruz de Tenerife      TENERIFE           ICOD DE LOS VINOS
# 390              Las Palmas  GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
# 391              Las Palmas  GRAN CANARIA   SAN BARTOLOMÉ DE TIRAJANA
# 392  Santa Cruz de Tenerife      TENERIFE           ICOD DE LOS VINOS
# 393              Las Palmas  GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
#
#      LOCALIDAD  CODIGO POSTAL TELEFONO DOMINIO INTERNET  \
# 0          NaN            NaN      NaN              NaN
# 1          NaN            NaN      NaN              NaN
# 2          NaN            NaN      NaN              NaN
# 3          NaN            NaN      NaN              NaN
# 4          NaN            NaN      NaN              NaN
# ..         ...            ...      ...              ...
# 389        NaN        38434.0      NaN              NaN
# 390        NaN        35014.0      NaN              NaN
# 391        NaN        35109.0      NaN              NaN
# 392        NaN        38434.0      NaN              NaN
# 393        NaN        35011.0      NaN              NaN
#
#                          EMAIL
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 389                        NaN
# 390  dogandcat2020.2@gmail.com
# 391                        NaN
# 392       klcaduanas@gmail.com
# 393                        NaN
#
# [394 rows x 16 columns]

# %% [markdown]
# FUNCIONES:

# %%
# Crea un df con los registros en los que aparece el nombre que le digo
def extraer_por_palabra(df, palabra):
    df_palabra = df[df['DENOMINACION'].str.lower().str.contains(palabra.lower())]
    return df_palabra

# %%
def eliminar_filas_listanegra(df, listanegra):
    # Crea una Serie booleana que indica si cada fila contiene alguna palabra de la lista negra
    mascara = df['DENOMINACION'].str.contains('|'.join(listanegra), case=False)
    # Elimina las filas que cumplen la condición anterior
    df = df[~mascara]
    return df

# %%
def restar_df(df_minuendo, df_sustraendo):
    df_diferencia = df_minuendo.merge(df_sustraendo, how='outer', indicator=True)
    df_diferencia = df_diferencia.loc[df_diferencia['_merge'] == 'left_only'].drop(columns='_merge')
    return df_diferencia

# %%
df_ok= extraer_por_palabra(df, 'animal')

# %%
df_ok
# Out:
#            Nº CANARIO.     C.I.F.  \
# 6     G1/S1/1092-86/TF        NaN
# 10    G1/S1/1134-87/TF        NaN
# 15    G1/S1/1681-91/TF        NaN
# 17     G1/S1/1782-92/P        NaN
# 21    G1/S1/2128-94/TF  G38342549
# ..                 ...        ...
# 377  G1/S1/26039-22/TF        NaN
# 380   G1/S1/26073-22/F        NaN
# 387  G1/S1/26212-22/TF        NaN
# 389  G1/S1/26236-23/TF        NaN
# 392  G1/S1/26258-23/TF        NaN
#
#                                           DENOMINACION      AMBITO  \
# 6       ESSI PARA LA PROTECCION DEL ANIMAL Y LA PLANTA  AUTONÓMICO
# 10                   ALBERGUE DE ANIMALES TENERIFE SUR       LOCAL
# 15              APRAM (PROTECTORA DE ANIMALES MADRUGA)     INSULAR
# 17          PALMERA PARA LA PROTECCION DE LOS ANIMALES     INSULAR
# 21   ASOCIACIÓN PROTECTORA DE ANIMALES Y LA NATURAL...     INSULAR
# ..                                                 ...         ...
# 377               ASOCIACION SANTUARIO ANIMAL PETRICOR     INSULAR
# 380                            PROTECTORA ANIMAL WORLD     INSULAR
# 387                      PROTECTORA DE ANIMALES "MAUI"  AUTONÓMICO
# 389          ASOCIACIÓN BIENESTAR ANIMAL YCODEM (ABAY)  AUTONÓMICO
# 392            FINCA CADA VIDA CUENTA BIENESTAR ANIMAL  AUTONÓMICO
#
#                       SECCION               ACTIVIDADES FECHA CONSTITUCIÓN  \
# 6    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         16/07/1986
# 10   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         26/12/1986
# 15   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         15/04/1991
# 17   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         14/11/1991
# 21   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         17/12/1993
# ..                        ...                       ...                ...
# 377  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         11/07/2022
# 380  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         23/01/2022
# 387  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         17/12/2022
# 389  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         05/09/2022
# 392  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         16/10/2022
#
#                                              DIRECCION  \
# 6                                  AVDA. SAN DIEGO, 47
# 10   GENERAL FRANCO, 43 - BAZAR ERICA - LOS CRISTIANOS
# 15                                 CAMINO MONTIJOS, 10
# 17              C/CRUZ ROJA N.6. 38700 S/C DE LA PALMA
# 21                                   c/ Duggi, 36 - 3º
# ..                                                 ...
# 377                               CAMINO LA LOMA Nº 7
# 380                              C/ VILLA SICER, Nº 11
# 387                           AVENIDA DE TINCER, Nº 32
# 389                     CALLE MAJUELO Nº 32 BUEN PASO
# 392                            CALLE LOS COSTALES Nº4
#
#                   PROVINCIA           ISLA                   MUNICIPIO  \
# 6    Santa Cruz de Tenerife       TENERIFE  SAN CRISTOBAL DE LA LAGUNA
# 10   Santa Cruz de Tenerife       TENERIFE                       ARONA
# 15   Santa Cruz de Tenerife       TENERIFE                  LA OROTAVA
# 17   Santa Cruz de Tenerife       LA PALMA      SANTA CRUZ DE LA PALMA
# 21   Santa Cruz de Tenerife       TENERIFE      SANTA CRUZ DE TENERIFE
# ..                      ...            ...                         ...
# 377  Santa Cruz de Tenerife       TENERIFE                    TEGUESTE
# 380              Las Palmas  FUERTEVENTURA                     TUINEJE
# 387  Santa Cruz de Tenerife       TENERIFE      SANTA CRUZ DE TENERIFE
# 389  Santa Cruz de Tenerife       TENERIFE           ICOD DE LOS VINOS
# 392  Santa Cruz de Tenerife       TENERIFE           ICOD DE LOS VINOS
#
#      LOCALIDAD  CODIGO POSTAL   TELEFONO DOMINIO INTERNET  \
# 6          NaN            NaN        NaN              NaN
# 10         NaN            NaN        NaN              NaN
# 15         NaN        38300.0        NaN              NaN
# 17         NaN            NaN  922573112              NaN
# 21         NaN        38004.0  922274844              NaN
# ..         ...            ...        ...              ...
# 377        NaN        38290.0        NaN              NaN
# 380        NaN        35629.0        NaN              NaN
# 387        NaN        38107.0        NaN              NaN
# 389        NaN        38434.0        NaN              NaN
# 392        NaN        38434.0        NaN              NaN
#
#                     EMAIL
# 6                     NaN
# 10                    NaN
# 15                    NaN
# 17                    NaN
# 21                    NaN
# ..                    ...
# 377                   NaN
# 380                   NaN
# 387                   NaN
# 389                   NaN
# 392  klcaduanas@gmail.com
#
# [156 rows x 16 columns]

# %%
df= restar_df(df, df_ok)

# %%
df
# Out:
#            Nº CANARIO. C.I.F.  \
# 0      G1/S1/243-76/TF    NaN
# 1      G1/S1/873-83/TF    NaN
# 2      G1/S1/959-84/TF    NaN
# 3     G1/S1/1018-85/TF    NaN
# 4     G1/S1/1026-85/TF    NaN
# ..                 ...    ...
# 386  G1/S1/26203-23/TF    NaN
# 388  G1/S1/26223-23/TF    NaN
# 390  G1/S1/26243-23/GC    NaN
# 391  G1/S1/26256-23/GC    NaN
# 393  G1/S1/26293-23/GC    NaN
#
#                                           DENOMINACION      AMBITO  \
# 0               PADRES Y AMIGOS DEL SORDO (A.S.P.A.S.)  PROVINCIAL
# 1                         TINERFEñA AMIGOS DEL CABALLO  PROVINCIAL
# 2                                      CAN DE TENERIFE  PROVINCIAL
# 3    DEFENSA, PROTEC., MANTENIMIENTO Y MEJORA PAT. ...  PROVINCIAL
# 4                                             CAN CLUB  AUTONÓMICO
# ..                                                 ...         ...
# 386  ASOCIACIÓN SIN ÁNIMO DE LUCRO REFUGIO DE AVES ...  AUTONÓMICO
# 388               ASOCIACIÓN DE CANARICULTORES TINERFE  AUTONÓMICO
# 390                             DOGANDCAT PET´S LOVERS   MUNICIPAL
# 391  DE ADIESTRADORES CANINOS DE CANARIAS "GT.BOCAL...  AUTONÓMICO
# 393                          GUANCHE DEL PRESA CANARIO  AUTONÓMICO
#
#                       SECCION               ACTIVIDADES FECHA CONSTITUCIÓN  \
# 0    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         27/05/1976
# 1    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         30/09/1983
# 2    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         05/11/1984
# 3    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         26/07/1985
# 4    Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         26/09/1985
# ..                        ...                       ...                ...
# 386  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         02/05/2022
# 388  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         04/10/2022
# 390  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         30/10/2022
# 391  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         15/01/2023
# 393  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         07/02/2023
#
#                                              DIRECCION  \
# 0               AVDA. LOS REYES CATOLICOS N.28-1 VDA.2
# 1                    CAMINO LA CORDILLERA, 2 - GUAMASA
# 2                                         C/ VIANA, 69
# 3                                  C/ HERMANO PEDRO, 9
# 4    RAMBLA GENERAL FRANCO, 135 BAJO - APTDO. CORRE...
# ..                                                 ...
# 386   LUGAR MOLLEDO S/N POLIGONO 9 PARCELA 929 MOLLEDO
# 388                         CALLE CANTILLO ABAJO Nº11A
# 390         CARRETERA DE MATA, Nº 85, TRASERA, 2º PISO
# 391                             LGAR. AYAGAURES, Nº 10
# 393  C/ LETRADO RAMÍREZ DORESTE, Nº 2, PLANTA BAJA ...
#
#                   PROVINCIA          ISLA                   MUNICIPIO  \
# 0    Santa Cruz de Tenerife      TENERIFE      SANTA CRUZ DE TENERIFE
# 1    Santa Cruz de Tenerife      TENERIFE  SAN CRISTOBAL DE LA LAGUNA
# 2    Santa Cruz de Tenerife      TENERIFE  SAN CRISTOBAL DE LA LAGUNA
# 3    Santa Cruz de Tenerife      TENERIFE                    VILAFLOR
# 4    Santa Cruz de Tenerife      TENERIFE      SANTA CRUZ DE TENERIFE
# ..                      ...           ...                         ...
# 386  Santa Cruz de Tenerife      TENERIFE          SANTIAGO DEL TEIDE
# 388  Santa Cruz de Tenerife      TENERIFE                LOS REALEJOS
# 390              Las Palmas  GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
# 391              Las Palmas  GRAN CANARIA   SAN BARTOLOMÉ DE TIRAJANA
# 393              Las Palmas  GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
#
#      LOCALIDAD  CODIGO POSTAL TELEFONO DOMINIO INTERNET  \
# 0          NaN            NaN      NaN              NaN
# 1          NaN            NaN      NaN              NaN
# 2          NaN            NaN      NaN              NaN
# 3          NaN            NaN      NaN              NaN
# 4          NaN            NaN      NaN              NaN
# ..         ...            ...      ...              ...
# 386        NaN        38690.0      NaN              NaN
# 388        NaN        38410.0      NaN              NaN
# 390        NaN        35014.0      NaN              NaN
# 391        NaN        35109.0      NaN              NaN
# 393        NaN        35011.0      NaN              NaN
#
#                          EMAIL
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 386                        NaN
# 388                        NaN
# 390  dogandcat2020.2@gmail.com
# 391                        NaN
# 393                        NaN
#
# [238 rows x 16 columns]

# %%
listanegra= ['canar','ave','caball','sordo','adiest','vegan','ornit','sanitar','manten','criad']

# %%
df= eliminar_filas_listanegra(df, listanegra)

# %%
df
# Out:
#            Nº CANARIO. C.I.F.                               DENOMINACION  \
# 2      G1/S1/959-84/TF    NaN                            CAN DE TENERIFE
# 4     G1/S1/1026-85/TF    NaN                                   CAN CLUB
# 5     G1/S1/1032-85/TF    NaN                                     GANIGO
# 11       G2/S1/9-89/TF    NaN  CLUB ESPAñOL DEL PERRO DE GANADO MAHORERO
# 13    G1/S1/1526-90/TF    NaN               CASA FAMILIAR DOLORES MEDINA
# ..                 ...    ...                                        ...
# 378  G1/S1/26042-22/GC    NaN                                MASQUEGATOS
# 379   G1/S1/26048-22/F    NaN                                 FUERTECATS
# 383  G1/S1/26150-22/TF    NaN             ASOCIACIÓN CANINA BLACK DOG K9
# 384  G1/S1/26160-22/GC    NaN                                ALMA GATUNA
# 390  G1/S1/26243-23/GC    NaN                     DOGANDCAT PET´S LOVERS
#
#          AMBITO                                   SECCION  \
# 2    PROVINCIAL                  Sección 1 - Asociaciones
# 4    AUTONÓMICO                  Sección 1 - Asociaciones
# 5    PROVINCIAL                  Sección 1 - Asociaciones
# 11     NACIONAL  Sección 1 - Asoc. Nacionales/Extranjeras
# 13   PROVINCIAL                  Sección 1 - Asociaciones
# ..          ...                                       ...
# 378   MUNICIPAL                  Sección 1 - Asociaciones
# 379     INSULAR                  Sección 1 - Asociaciones
# 383  AUTONÓMICO                  Sección 1 - Asociaciones
# 384   MUNICIPAL                  Sección 1 - Asociaciones
# 390   MUNICIPAL                  Sección 1 - Asociaciones
#
#                   ACTIVIDADES FECHA CONSTITUCIÓN  \
# 2    SOBRE ANIMALES Y PLANTAS         05/11/1984
# 4    SOBRE ANIMALES Y PLANTAS         26/09/1985
# 5    SOBRE ANIMALES Y PLANTAS         12/11/1985
# 11   SOBRE ANIMALES Y PLANTAS                NaN
# 13   SOBRE ANIMALES Y PLANTAS         08/05/1990
# ..                        ...                ...
# 378  SOBRE ANIMALES Y PLANTAS         23/05/2022
# 379  SOBRE ANIMALES Y PLANTAS         22/07/2022
# 383  SOBRE ANIMALES Y PLANTAS         06/03/2020
# 384  SOBRE ANIMALES Y PLANTAS         12/09/2022
# 390  SOBRE ANIMALES Y PLANTAS         30/10/2022
#
#                                              DIRECCION  \
# 2                                         C/ VIANA, 69
# 4    RAMBLA GENERAL FRANCO, 135 BAJO - APTDO. CORRE...
# 5              C/ GANDHI, 19 - BARRIADA GARCIA ESCAMEZ
# 11                 CAMINO DE GUILLEN 11 - LA ESPERANZA
# 13                         AVDA. LUCAS VEGA, 39 - BAJO
# ..                                                 ...
# 378                                 C/ CARVAJAL, Nº 79
# 379   C/ ACEBUCHE, Nº 14, URB LA CAPELLANÍA, CORRALEJO
# 383                               CAMINO DE BORUGA S/N
# 384            C/ LOMO LA PLANA, Nº 24, PORTAL 1, 1º A
# 390         CARRETERA DE MATA, Nº 85, TRASERA, 2º PISO
#
#                   PROVINCIA           ISLA                   MUNICIPIO  \
# 2    Santa Cruz de Tenerife       TENERIFE  SAN CRISTOBAL DE LA LAGUNA
# 4    Santa Cruz de Tenerife       TENERIFE      SANTA CRUZ DE TENERIFE
# 5    Santa Cruz de Tenerife       TENERIFE      SANTA CRUZ DE TENERIFE
# 11   Santa Cruz de Tenerife       TENERIFE                  EL ROSARIO
# 13   Santa Cruz de Tenerife       TENERIFE  SAN CRISTOBAL DE LA LAGUNA
# ..                      ...            ...                         ...
# 378              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
# 379              Las Palmas  FUERTEVENTURA                    LA OLIVA
# 383  Santa Cruz de Tenerife       TENERIFE                      GÜIMAR
# 384              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
# 390              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
#
#      LOCALIDAD  CODIGO POSTAL TELEFONO DOMINIO INTERNET  \
# 2          NaN            NaN      NaN              NaN
# 4          NaN            NaN      NaN              NaN
# 5          NaN            NaN      NaN              NaN
# 11         NaN            NaN      NaN              NaN
# 13         NaN            NaN      NaN              NaN
# ..         ...            ...      ...              ...
# 378        NaN        35004.0      NaN              NaN
# 379        NaN        35660.0      NaN              NaN
# 383        NaN        38500.0      NaN              NaN
# 384        NaN        35019.0      NaN              NaN
# 390        NaN        35014.0      NaN              NaN
#
#                          EMAIL
# 2                          NaN
# 4                          NaN
# 5                          NaN
# 11                         NaN
# 13                         NaN
# ..                         ...
# 378                        NaN
# 379                        NaN
# 383                        NaN
# 384                        NaN
# 390  dogandcat2020.2@gmail.com
#
# [130 rows x 16 columns]

# %%
gat= extraer_por_palabra(df, 'gat')

# %%
gat
# Out:
#            Nº CANARIO. C.I.F.  \
# 88     G1/S1/9625-03/F    NaN
# 201  G1/S1/18557-12/TF    NaN
# 202  G1/S1/18593-12/TF    NaN
# 224  G1/S1/20395-14/GC    NaN
# 227  G1/S1/20692-15/GC    NaN
# 251  G1/S1/21816-16/GC    NaN
# 279  G1/S1/23078-17/GC    NaN
# 282   G1/S1/23245-17/F    NaN
# 328  G1/S1/24690-20/GC    NaN
# 373  G1/S1/25971-22/GC    NaN
# 378  G1/S1/26042-22/GC    NaN
# 384  G1/S1/26160-22/GC    NaN
#
#                                           DENOMINACION      AMBITO  \
# 88            KITZ'N KATZ,SOCIEDAD BENEFICA PARA GATOS     INSULAR
# 201  ASOCIACION ASOCAT:ASOCIACION  PARA CUIDAR  Y A...     INSULAR
# 202  ASOCIACIÓN POR LA PROTECCIÓN DE LOS GATOS CALL...  AUTONÓMICO
# 224                           LOS GATOS DE CAROL & CÍA     INSULAR
# 227                        PROTECTORA DE GATOS GATTARA  AUTONÓMICO
# 251                                    ES TU GATOPCIÓN  AUTONÓMICO
# 279  DE GESTORAS DE COLONIAS DE GATOS DE ARUCAS "TU...   MUNICIPAL
# 282                   PARA PERROS Y GATOS TODOMASCOTAS  AUTONÓMICO
# 328                          GATOS DE LA CALLE EN G.C.     INSULAR
# 373                   PELUDITOS GATUNOS DE TORI Y MILA   MUNICIPAL
# 378                                        MASQUEGATOS   MUNICIPAL
# 384                                        ALMA GATUNA   MUNICIPAL
#
#                       SECCION               ACTIVIDADES FECHA CONSTITUCIÓN  \
# 88   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         15/06/2003
# 201  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS                NaN
# 202  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS                NaN
# 224  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         04/08/2014
# 227  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         22/12/2014
# 251  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         10/11/2015
# 279  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         05/05/2017
# 282  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         07/06/2017
# 328  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         29/08/2019
# 373  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         29/03/2022
# 378  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         23/05/2022
# 384  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         12/09/2022
#
#                                              DIRECCION  \
# 88                       C/ CASILLAS DE MORALES, Nº 15
# 201        CALLE PIEDRA REDONDA, EDIFICIO SERGIO 2-3-f
# 202                        CALLE MARTA, 9 - (CHIMICHE)
# 224                 C/ JUAN REJÓN, Nº 7, 5º C (APT 15)
# 227  C/ GUSTAVO J. NAVARRO NIETO, Nº 1, PISO 9, PUE...
# 251                       C/ HOYA DEL ENAMORADO, Nº 45
# 279               C/ PINTOR VELÁZQUEZ, Nº 41, GARAGE 8
# 282   C/ JUAN SEBASTIÁN ELCANO, Nº 21, 3º H, CORRALEJO
# 328                            C/ ALMANSA, Nº 51, 1º E
# 373          C/ FRANCISCO INGLOTT ARTILES, Nº 28, 6º E
# 378                                 C/ CARVAJAL, Nº 79
# 384            C/ LOMO LA PLANA, Nº 24, PORTAL 1, 1º A
#
#                   PROVINCIA           ISLA                   MUNICIPIO  \
# 88               Las Palmas  FUERTEVENTURA                     ANTIGUA
# 201  Santa Cruz de Tenerife       TENERIFE                       ADEJE
# 202  Santa Cruz de Tenerife       TENERIFE         GRANADILLA DE ABONA
# 224              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
# 227              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
# 251              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
# 279              Las Palmas   GRAN CANARIA                      ARUCAS
# 282              Las Palmas  FUERTEVENTURA                    LA OLIVA
# 328              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
# 373              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
# 378              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
# 384              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
#
#      LOCALIDAD  CODIGO POSTAL   TELEFONO DOMINIO INTERNET EMAIL
# 88         NaN        35638.0        NaN              NaN   NaN
# 201        NaN        38670.0  654902511              NaN   NaN
# 202        NaN        38594.0  622083900              NaN   NaN
# 224        NaN        35008.0        NaN              NaN   NaN
# 227        NaN        35011.0        NaN              NaN   NaN
# 251        NaN        35019.0        NaN              NaN   NaN
# 279        NaN        35411.0        NaN              NaN   NaN
# 282        NaN        35660.0        NaN              NaN   NaN
# 328        NaN        35010.0        NaN              NaN   NaN
# 373        NaN        35016.0        NaN              NaN   NaN
# 378        NaN        35004.0        NaN              NaN   NaN
# 384        NaN        35019.0        NaN              NaN   NaN

# %%
df_ok = pd.concat([df_ok , gat], axis=0)

# %%
df= restar_df(df, df_ok)

# %%
felin= extraer_por_palabra(df, 'felin')

# %%
felin
# Out:
#            Nº CANARIO. C.I.F.  \
# 72   G1/S1/16700-10/TF    NaN
# 86   G1/S1/19347-13/GC    NaN
# 99   G1/S1/22347-16/GC    NaN
# 111  G1/S1/24430-19/TF    NaN
# 118  G1/S1/25574-21/TF    NaN
# 119  G1/S1/25577-21/GC    NaN
# 121  G1/S1/25822-22/TF    NaN
# 122  G1/S1/25848-22/GC    NaN
# 124  G1/S1/25973-22/GC    NaN
#
#                                           DENOMINACION      AMBITO  \
# 72                                 PRO FELINA TENERIFE     INSULAR
# 86                                     LIBERTAD FELINA     INSULAR
# 99                        COLONIAS FELINAS MAMÁ MININA  AUTONÓMICO
# 111                             ASOCIACIÓN FELINA NEKO  AUTONÓMICO
# 118                              ÁNGELES FELINOS ARONA  AUTONÓMICO
# 119  ACCIÓN FELINA GESTORES DE COLONIAS DE SAN BART...  AUTONÓMICO
# 121                        PROTECTORA FELINA FRIDA-CAT   MUNICIPAL
# 122                           BIGOTES FELINOS TROPILUA   MUNICIPAL
# 124             EL LEGADO DE LOLITA - COLONIAS FELINAS     INSULAR
#
#                       SECCION               ACTIVIDADES FECHA CONSTITUCIÓN  \
# 72   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS                NaN
# 86   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         08/03/2013
# 99   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         10/10/2016
# 111  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         07/06/2019
# 118  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         05/04/2021
# 119  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         05/08/2021
# 121  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         10/02/2022
# 122  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         15/02/2022
# 124  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         22/05/2022
#
#                                      DIRECCION               PROVINCIA  \
# 72            AVENIDA ISLAS CANARIAS, 87 LOCAL  Santa Cruz de Tenerife
# 86                  C/ FRANCISCO SERRANO, Nº 3              Las Palmas
# 99         C/ EL BAJO RISCO, Nº 6 - LA ATALAYA              Las Palmas
# 111          C/ PITERILLAS, Nº 6 - SAN ANTONIO  Santa Cruz de Tenerife
# 118             C/ BÉLGICA, Nº 3, LAS GALLETAS  Santa Cruz de Tenerife
# 119      C/ SAN SALVADOR, Nº 2, BLOQUE 5, 3º A              Las Palmas
# 121            C/ LAS PARRAS, Nº 12, PISO BAJO  Santa Cruz de Tenerife
# 122                C/ MARIE CURIE, Nº 15, 5º B              Las Palmas
# 124  PASAJE ANTONIO RAMÍREZ GRAÑA, Nº 4, PBJ A              Las Palmas
#
#              ISLA                   MUNICIPIO  LOCALIDAD  CODIGO POSTAL  \
# 72       TENERIFE      SANTA CRUZ DE TENERIFE        NaN        38007.0
# 86   GRAN CANARIA                     INGENIO        NaN        35250.0
# 99   GRAN CANARIA               SANTA BRÍGIDA        NaN        35307.0
# 111      TENERIFE      LA MATANZA DE ACENTEJO        NaN        38379.0
# 118      TENERIFE                       ARONA        NaN        38631.0
# 119  GRAN CANARIA   SAN BARTOLOMÉ DE TIRAJANA        NaN        35109.0
# 121      TENERIFE                   EL SAUZAL        NaN        38360.0
# 122  GRAN CANARIA  LAS PALMAS DE GRAN CANARIA        NaN        35015.0
# 124  GRAN CANARIA  LAS PALMAS DE GRAN CANARIA        NaN        35018.0
#
#                 TELEFONO                                   DOMINIO INTERNET  \
# 72   922204757/646427007                                                NaN
# 86                   NaN                                                NaN
# 99                   NaN  DOMICILIO ANTERIOR: C/ NARDO, Nº 11 , TELDE (3...
# 111                  NaN                                                NaN
# 118            677648310                                                NaN
# 119                  NaN                                                NaN
# 121                  NaN                                                NaN
# 122                  NaN                                                NaN
# 124                  NaN                                                NaN
#
#                         EMAIL
# 72          felina64@yahoo.es
# 86                        NaN
# 99   mama.minina.gc@gmail.com
# 111                       NaN
# 118       aunxaki@hotmail.com
# 119                       NaN
# 121                       NaN
# 122                       NaN
# 124                       NaN

# %%
df_ok = pd.concat([df_ok , felin], axis=0)

# %%
df= restar_df(df, df_ok)

# %%
cat= extraer_por_palabra(df, 'cat')

# %%
cat
# Out:
#            Nº CANARIO. C.I.F.  \
# 45   G1/S1/12496-05/TF    NaN
# 78   G1/S1/17700-12/TF    NaN
# 97    G1/S1/23526-18/L    NaN
# 100  G1/S1/23618-18/TF    NaN
# 107   G1/S1/25337-21/L    NaN
# 115   G1/S1/26048-22/F    NaN
# 117  G1/S1/26243-23/GC    NaN
#
#                                           DENOMINACION      AMBITO  \
# 45   ASOCIACION DINGO`S DOG AND CAT SANTUARY AND BO...  AUTONÓMICO
# 78                    ASOCIACION CATS WELFARE TENERIFE     INSULAR
# 97                                    FREDDYS CATHOUSE  AUTONÓMICO
# 100      ASOCIACIÓN SANGHA SAN MIGUEL GRANJA EDUCATIVA  AUTONÓMICO
# 107                           LANZAROTE CAT PROTECTION     INSULAR
# 115                                         FUERTECATS     INSULAR
# 117                             DOGANDCAT PET´S LOVERS   MUNICIPAL
#
#                       SECCION               ACTIVIDADES FECHA CONSTITUCIÓN  \
# 45   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         13/09/2004
# 78   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS                NaN
# 97   Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         18/04/2018
# 100  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         12/04/2018
# 107  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         20/03/2021
# 115  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         22/07/2022
# 117  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         30/10/2022
#
#                                              DIRECCION  \
# 45                            C/FINCA HOYA LAS PIEDRAS
# 78   CALLE ROQUE DE LOS MUCHACHOS, BALCON DEL DUQUE...
# 97   C/ IRLANDA, Nº 93, URB. FARO PARK FASE 1-2, PL...
# 100              C/ EL MORRO, 46 - SAN MIGUEL DE ABONA
# 107                C/ CAMINO LAS CASAÑAS, Nº 3, MÁCHER
# 115   C/ ACEBUCHE, Nº 14, URB LA CAPELLANÍA, CORRALEJO
# 117         CARRETERA DE MATA, Nº 85, TRASERA, 2º PISO
#
#                   PROVINCIA           ISLA                   MUNICIPIO  \
# 45   Santa Cruz de Tenerife       TENERIFE               GUÍA DE ISORA
# 78   Santa Cruz de Tenerife       TENERIFE                       ADEJE
# 97               Las Palmas      LANZAROTE                       YAIZA
# 100  Santa Cruz de Tenerife       TENERIFE                  SAN MIGUEL
# 107              Las Palmas      LANZAROTE                        TÍAS
# 115              Las Palmas  FUERTEVENTURA                    LA OLIVA
# 117              Las Palmas   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA
#
#      LOCALIDAD  CODIGO POSTAL   TELEFONO DOMINIO INTERNET  \
# 45         NaN        38687.0  609433396              NaN
# 78         NaN        38660.0  662524006              NaN
# 97         NaN        35580.0        NaN              NaN
# 100        NaN        38628.0        NaN              NaN
# 107        NaN        35571.0        NaN              NaN
# 115        NaN        35660.0        NaN              NaN
# 117        NaN        35014.0        NaN              NaN
#
#                          EMAIL
# 45                         NaN
# 78                         NaN
# 97                         NaN
# 100                        NaN
# 107                        NaN
# 115                        NaN
# 117  dogandcat2020.2@gmail.com

# %%
df_ok = pd.concat([df_ok , cat], axis=0)

# %%
df= restar_df(df, df_ok)

# %%
can= extraer_por_palabra(df, 'can')

# %%
can
# Out:
#            Nº CANARIO.     C.I.F.  \
# 0      G1/S1/959-84/TF        NaN
# 1     G1/S1/1026-85/TF        NaN
# 38   G1/S1/10271-99/GC        NaN
# 47   G1/S1/12747-90/TF  G38235701
# 59   G1/S1/14839-08/TF  G38950903
# 72    G1/S1/17378-11/P        NaN
# 79    G1/S1/17967-12/P  G76565423
# 92    G1/S1/22650-17/F        NaN
# 101  G1/S1/24572-19/GC        NaN
# 104  G1/S1/25501-21/GC        NaN
# 105  G1/S1/25813-22/GC        NaN
# 107  G1/S1/26150-22/TF        NaN
# 72         NaN        38700.0  619203368              NaN                  NaN
# 79         NaN        38750.0  679748600              NaN                  NaN
# 92         NaN        35650.0        NaN              NaN                  NaN
# 101        NaN        35460.0        NaN              NaN                  NaN
# 104        NaN        35450.0        NaN              NaN                  NaN
# 105        NaN        35309.0        NaN              NaN                  NaN
# 107        NaN        38500.0        NaN              NaN                  NaN

# %%
can= eliminar_filas_listanegra(can, ['depor','educ','rescu','integ','trabajo','club'])

# %%
can
# Out:
#            Nº CANARIO.     C.I.F.                          DENOMINACION  \
# 0      G1/S1/959-84/TF        NaN                       CAN DE TENERIFE
# 47   G1/S1/12747-90/TF  G38235701           SOCIEDAD CANINA DE TENERIFE
# 59   G1/S1/14839-08/TF  G38950903  ASOCIACIÓN PROTECTORA CANIS PROFICIO
# 79    G1/S1/17967-12/P  G76565423       ASOCIACION CANINA CHUCHO'S PARK
# 104  G1/S1/25501-21/GC        NaN   SOCIAL AMPLIANDO CONCIENCIA UNCANNY
# 107  G1/S1/26150-22/TF        NaN        ASOCIACIÓN CANINA BLACK DOG K9
#
#          AMBITO                   SECCION               ACTIVIDADES  \
# 0    PROVINCIAL  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS
# 47   AUTONÓMICO  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS
# 59    MUNICIPAL  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS
# 79      INSULAR  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS
# 104  AUTONÓMICO  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS
# 107  AUTONÓMICO  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS
#
#     FECHA CONSTITUCIÓN                        DIRECCION  \
# 0           05/11/1984                     C/ VIANA, 69
# 47                 NaN  C/. CASTILLO Nº 41, OFICINA 219
# 59          22/02/2008               C/ Malvasia, nº 34
# 79                 NaN       C/ HOYA DEL CASTAÑERO Nº 1
# 104         15/03/2021         CERCADOS DE MERINO, Nº 5
# 107         06/03/2020             CAMINO DE BORUGA S/N
#
#                   PROVINCIA          ISLA                   MUNICIPIO  \
# 0    Santa Cruz de Tenerife      TENERIFE  SAN CRISTOBAL DE LA LAGUNA
# 47   Santa Cruz de Tenerife      TENERIFE      SANTA CRUZ DE TENERIFE
# 59   Santa Cruz de Tenerife      TENERIFE      SANTA CRUZ DE TENERIFE
# 79   Santa Cruz de Tenerife      LA PALMA                     EL PASO
# 104              Las Palmas  GRAN CANARIA         SANTA MARÍA DE GUÍA
# 107  Santa Cruz de Tenerife      TENERIFE                      GÜIMAR
#
#      LOCALIDAD  CODIGO POSTAL   TELEFONO DOMINIO INTERNET                EMAIL
# 0          NaN            NaN        NaN              NaN                  NaN
# 47         NaN        38003.0  922288435              NaN                  NaN
# 59         NaN        38107.0  640264948              NaN  tereungen@gmail.com
# 79         NaN        38750.0  679748600              NaN                  NaN
# 104        NaN        35450.0        NaN              NaN                  NaN
# 107        NaN        38500.0        NaN              NaN                  NaN

# %%
df_ok = pd.concat([df_ok , can], axis=0)

# %%
df= eliminar_filas_listanegra(df, ['can','depor','educ','rescu','integ','trabajo','club'])

# %%
df= eliminar_filas_listanegra(df, ['ecues','caza','gall','rey','valle','san jose','gani','dolor',
                                  'beññi','wolf','inter','baña','omic','equi','burr','niñ','micol'])

# %%
df
# Out:
#           Nº CANARIO.     C.I.F.  \
# 7    G1/S1/1895-92/TF        NaN
# 8    G1/S1/2143-94/TF        NaN
# 10   G1/S1/2365-95/TF        NaN
# 11   G1/S1/2378-95/TF        NaN
# 15   G1/S1/2911-97/TF        NaN
# 20   G1/S1/6955-00/TF        NaN
# 21   G1/S1/6994-91/TF        NaN
# 22   G1/S1/7156-99/TF        NaN
# 28   G1/S1/8610-02/TF        NaN
# 29   G1/S1/8801-02/TF        NaN
# 32   G1/S1/9490-03/TF        NaN
# 34   G1/S1/9601-81/TF  G38034401
# 35   G1/S1/9647-03/GC        NaN
# 36   G1/S1/9728-02/GC        NaN
# 39  G1/S1/10795-04/TF        NaN
# 40   G1/S1/11232-05/F        NaN
# 41  G1/S1/11357-05/GC        NaN
# 42  G1/S1/11379-92/TF  G38310553
# 43  G1/S1/11506-05/GC        NaN
# 46  G1/S1/12642-05/TF        NaN
# 48  G1/S1/12973-01/TF  G38629127
# 49   G1/S1/12985-00/P        NaN
# 53  G1/S1/13968-06/GO        NaN
# 54  G1/S1/14028-06/TF        NaN
# 55   G1/S1/14189-07/H        NaN
# 57   G1/S1/14760-08/F        NaN
# 58   G1/S1/14803-08/H        NaN
# 60   G1/S1/14858-08/P        NaN
# 62   G1/S1/15002-08/P        NaN
# 63  G1/S1/15088-08/TF  G38948303
# 66   G1/S1/15543-09/P        NaN
# 67   G1/S1/16259-10/P        NaN
# 73   G1/S1/17445-11/L        NaN
# 74  G1/S1/17518-11/TF        NaN
# 75  G1/S1/17521-11/TF        NaN
# 80   G1/S1/19190-13/P  G76604198
# 83   G1/S1/19523-13/L        NaN
# 84  G1/S1/19644-13/GC        NaN
# 85  G1/S1/20215-14/GC        NaN
# 86  G1/S1/21278-15/GC        NaN
# 87  G1/S1/21360-15/GC        NaN
# 88  G1/S1/21430-15/GC        NaN
# 89  G1/S1/21577-16/GC        NaN
# 96  G1/S1/23572-18/TF  G76770502
#
#                                          DENOMINACION      AMBITO  \
# 7   SABINO BERTHELOT PARA LA PROTEC.DEL PATR.NAT D...  AUTONÓMICO
# 8                                              BEÑIMA   MUNICIPAL
# 10                WOFGANG KOHLER DE TENERIFE (A.W.K.)   MUNICIPAL
# 11                 I.I.P. PROYECTO AMBIENTAL TENERIFE     INSULAR
# 15  COORDINADORA EN DEFENSA DE LA VEGA DE AGUERE, ...  AUTONÓMICO
# 20  DE AMIGOS DE LA PLAYA DE LAS TERESITAS ANAGA Y...  AUTONÓMICO
# 21  DE PADRES Y DEL PROPIO INVIDENTE CON OTRAS DEF...  PROVINCIAL
# 22                     AFECTADOS DEL CAMINO LA CAÑADA  PROVINCIAL
# 28                        ASOCIACION INFANTES CUBANOS  AUTONÓMICO
# 29         ASOCIACION COMITE DE EMPRESA HOTEL MARITIM       LOCAL
# 32     ASOCIACION TINERFEÑA DE CETRERIA PELEGRINOIDES  PROVINCIAL
# 34   PRO CASAS DE FAMILIA DE S/C DE TENERIFE (ACAFAM)  AUTONÓMICO
# 35                              JARDIN DES HESPERIDES  AUTONÓMICO
# 48  Sección 1 - Asociaciones
# 49  Sección 1 - Asociaciones
# 53  Sección 1 - Asociaciones
# 54  Sección 1 - Asociaciones
# 55  Sección 1 - Asociaciones
# 57  Sección 1 - Asociaciones
# 58  Sección 1 - Asociaciones
# 60  Sección 1 - Asociaciones
# 62  Sección 1 - Asociaciones
# 63  Sección 1 - Asociaciones
# 66  Sección 1 - Asociaciones
# 67  Sección 1 - Asociaciones
# 73  Sección 1 - Asociaciones
# 74  Sección 1 - Asociaciones
# 75  Sección 1 - Asociaciones
# 80  Sección 1 - Asociaciones
# 83  Sección 1 - Asociaciones
# 84  Sección 1 - Asociaciones
# 85  Sección 1 - Asociaciones
# 86  Sección 1 - Asociaciones
# 87  Sección 1 - Asociaciones
# 88  Sección 1 - Asociaciones
# 89  Sección 1 - Asociaciones
# 96  Sección 1 - Asociaciones
#
#                                           ACTIVIDADES FECHA CONSTITUCIÓN  \
# 7                            SOBRE ANIMALES Y PLANTAS         01/06/1992
# 8                            SOBRE ANIMALES Y PLANTAS         06/02/1994
# 10                           SOBRE ANIMALES Y PLANTAS         17/01/1995
# 11                           SOBRE ANIMALES Y PLANTAS         09/11/1994
# 15                           SOBRE ANIMALES Y PLANTAS         24/04/1997
# 20                           SOBRE ANIMALES Y PLANTAS         27/01/2000
# 21                           SOBRE ANIMALES Y PLANTAS                NaN
# 22                           SOBRE ANIMALES Y PLANTAS         02/02/1999
# 28                           SOBRE ANIMALES Y PLANTAS         13/09/2001
# 29                           SOBRE ANIMALES Y PLANTAS                NaN
# 32                           SOBRE ANIMALES Y PLANTAS         12/03/2003
# 34                           SOBRE ANIMALES Y PLANTAS                NaN
# 35                           SOBRE ANIMALES Y PLANTAS         18/07/2003
# 36         SOCIO-CULTURALES; SOBRE ANIMALES Y PLANTAS                NaN
# 39                           SOBRE ANIMALES Y PLANTAS         20/06/2004
# 40                           SOBRE ANIMALES Y PLANTAS         10/11/2004
# 41                           SOBRE ANIMALES Y PLANTAS         15/12/2004
# 42                           SOBRE ANIMALES Y PLANTAS         06/05/1992
# 43                           SOBRE ANIMALES Y PLANTAS         16/03/2005
# 46                           SOBRE ANIMALES Y PLANTAS         15/09/2004
# 48                           SOBRE ANIMALES Y PLANTAS                NaN
# 49                           SOBRE ANIMALES Y PLANTAS         04/01/2000
# 53                           SOBRE ANIMALES Y PLANTAS         21/04/2006
# 54                           SOBRE ANIMALES Y PLANTAS         21/03/2006
# 55                           SOBRE ANIMALES Y PLANTAS         15/04/2006
# 57                           SOBRE ANIMALES Y PLANTAS         22/02/2008
# 58                           SOBRE ANIMALES Y PLANTAS         16/03/2007
# 60                           SOBRE ANIMALES Y PLANTAS         11/07/2007
# 62                           SOBRE ANIMALES Y PLANTAS         05/03/2008
# 63                           SOBRE ANIMALES Y PLANTAS         14/04/2008
# 66                           SOBRE ANIMALES Y PLANTAS         09/03/2009
# 67                           SOBRE ANIMALES Y PLANTAS                NaN
# 57  FUERTEVENTURA          PUERTO DEL ROSARIO        NaN        35600.0
# 58      EL HIERRO                    VALVERDE        NaN            NaN
# 60       LA PALMA                   TAZACORTE        NaN        38770.0
# 62       LA PALMA                     GARAFÍA        NaN        38712.0
# 63       TENERIFE                       ARONA        NaN        38650.0
# 66       LA PALMA      SANTA CRUZ DE LA PALMA        NaN            NaN
# 67       LA PALMA                     EL PASO        NaN        38750.0
# 73      LANZAROTE                       YAIZA        NaN        35570.0
# 74       TENERIFE                      GÜIMAR        NaN        38500.0
# 75       TENERIFE           PUERTO DE LA CRUZ        NaN        38340.0
# 80       LA PALMA                  PUNTALLANA        NaN        38715.0
# 83      LANZAROTE                       HARÍA        NaN        35520.0
# 84   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA        NaN        35011.0
# 85   GRAN CANARIA                      ARUCAS        NaN        35410.0
# 86   GRAN CANARIA                     INGENIO        NaN        35250.0
# 87   GRAN CANARIA                     AGÜIMES        NaN            NaN
# 88   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA        NaN        35004.0
# 89   GRAN CANARIA  LAS PALMAS DE GRAN CANARIA        NaN        35001.0
# 96       TENERIFE                      GÜIMAR        NaN        38500.0
#
#         TELEFONO         DOMINIO INTERNET                                EMAIL
# 7            NaN                      NaN                                  NaN
# 8            NaN                      NaN                                  NaN
# 10           NaN                      NaN                                  NaN
# 11           NaN                      NaN                                  NaN
# 15           NaN                      NaN                                  NaN
# 20           NaN                      NaN                                  NaN
# 21           NaN                      NaN                                  NaN
# 22           NaN                      NaN                                  NaN
# 28           NaN                      NaN                                  NaN
# 29           NaN                      NaN                                  NaN
# 32           NaN                      NaN                                  NaN
# 34    922252285/                      NaN                                  NaN
# 35           NaN                      NaN                                  NaN
# 36           NaN                      NaN                                  NaN
# 39  922 25 51 75                      NaN                                  NaN
# 40           NaN                      NaN                                  NaN
# 41           NaN                      NaN                                  NaN
# 42     922385557                      NaN              administracion@antad.es
# 43           NaN                      NaN                                  NaN
# 46     609433396                      NaN                                  NaN
# 48     649364883                      NaN                                  NaN
# 49           NaN                      NaN                                  NaN
# 53           NaN                      NaN                                  NaN
# 54           NaN                      NaN                                  NaN
# 55           NaN                      NaN                                  NaN
# 57    928/879352                      NaN                                  NaN
# 58     922551220                      NaN                                  NaN
# 60           NaN                      NaN                                  NaN
# 62           NaN                      NaN                                  NaN
# 63           NaN                      NaN                                  NaN
# 66     691442289                      NaN                                  NaN
# 67     690127289                      NaN             taburiente27@hotmail.com
# 73           NaN                      NaN                                  NaN
# 74  661-30-19-72                      NaN                                  NaN
# 75     607280519                      NaN                                  NaN
# 80           NaN                      NaN                                  NaN
# 83           NaN                      NaN                                  NaN
# 84     928205676                      NaN  info.adiestramientocanino@gmail.com
# 85           NaN                      NaN                                  NaN
# 86           NaN                      NaN                                  NaN
# 87           NaN                      NaN                                  NaN
# 88           NaN                      NaN                                  NaN
# 89           NaN  APARTADO DE CORREOS 131                           680-273643
# 96           NaN                      NaN    santuariojosefinarivero@gmail.com

# %%
pet= extraer_por_palabra(df, 'pet')

# %%
pet
# Out:
#           Nº CANARIO. C.I.F. DENOMINACION      AMBITO  \
# 87  G1/S1/21360-15/GC    NaN  PET PALS GC  AUTONÓMICO
#
#                      SECCION               ACTIVIDADES FECHA CONSTITUCIÓN  \
# 87  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         01/01/2015
#
#                                  DIRECCION   PROVINCIA          ISLA  \
# 87  C/ VILLA PALMERAL, Nº 12, LOMO DE CRUZ  Las Palmas  GRAN CANARIA
#
#    MUNICIPIO  LOCALIDAD  CODIGO POSTAL TELEFONO DOMINIO INTERNET EMAIL
# 87   AGÜIMES        NaN            NaN      NaN              NaN   NaN

# %%
df_ok = pd.concat([df_ok , pet], axis=0)

# %%
df= eliminar_filas_listanegra(df, ['pet'])

# %%
aban= extraer_por_palabra(df, 'aban')

# %%
aban
# Out:
#           Nº CANARIO. C.I.F.   DENOMINACION      AMBITO  \
# 88  G1/S1/21430-15/GC    NaN  ABANDONO CERO  AUTONÓMICO
#
#                      SECCION               ACTIVIDADES FECHA CONSTITUCIÓN  \
# 88  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         21/10/2015
#
#                   DIRECCION   PROVINCIA          ISLA  \
# 88  C/ AGUADULCE, Nº 74, 2º  Las Palmas  GRAN CANARIA
#
#                      MUNICIPIO  LOCALIDAD  CODIGO POSTAL TELEFONO  \
# 88  LAS PALMAS DE GRAN CANARIA        NaN        35004.0      NaN
#
#    DOMINIO INTERNET EMAIL
# 88              NaN   NaN

# %%
df_ok = pd.concat([df_ok , aban], axis=0)

# %%
df= eliminar_filas_listanegra(df, ['aban'])

# %%
list(df['DENOMINACION'])
# Out:
# ['SABINO BERTHELOT PARA LA PROTEC.DEL PATR.NAT DE MAKARONESIA',
#  'BEÑIMA',
#  'WOFGANG KOHLER DE TENERIFE (A.W.K.)',
#  'I.I.P. PROYECTO AMBIENTAL TENERIFE',
#  'COORDINADORA EN DEFENSA DE LA VEGA DE AGUERE, CODEVA',
#  'DE AMIGOS DE LA PLAYA DE LAS TERESITAS ANAGA Y SU LITORAL. AAPTAL.',
#  'DE PADRES Y DEL PROPIO INVIDENTE CON OTRAS DEFICIENCIAS ASOCIADAS (ASINDE)',
#  'AFECTADOS DEL CAMINO LA CAÑADA',
#  'ASOCIACION INFANTES CUBANOS',
#  'ASOCIACION COMITE DE EMPRESA HOTEL MARITIM',
#  'ASOCIACION TINERFEÑA DE CETRERIA PELEGRINOIDES',
#  'PRO CASAS DE FAMILIA DE S/C DE TENERIFE (ACAFAM)',
#  'JARDIN DES HESPERIDES',
#  'AMIGOS DEL DRAGO ACAD',
#  'ASOCIACIÓN AMIGOS DEL PODENCO DEL SUR  "PODENSUR"',
#  'AMIGOS DE LA CINEGETICA Y ESPECIES PROTEGIDAS',
#  '4 PATAS NEWS',
#  'ASOCIACIÓN “ANTAD – ADICCIONES”',
#  'GRUPO DE OBEDIENCIA DEL PERRO DE COBRO',
#  'FIDO ASOCIACION DE PROPIETARIO DE MASCOTAS',
#  'SIRIUS',
#  'DE APICULTORES BENAHORITAS (ASABE)',
#  'Asociación Atlantic Care',
#  'VIII Simposium de Relaciones Hídricas en las Plantas',
#  'Asociación AMILOBO',
#  'ASOCIACIÓN PARA LA CONSERVACIÓN DEL PERRO MAJORERO (ACPM)',
#  'ASOCIACION ESPAÑOLA DEL PODENCO ENANO DE EL HIERRO',
#  'ASOCIACION GRUPO DE AMIGOS COLOMBÓFILOS DE TAZACORTE',
#  'ASOCIACIÓN BIOAPI-APICULTORES ECOLOGICOS DE ABEJA PEQUEÑA NEGRA',
#  'ASOCIACION WHALE FUND',
#  'ASOCIACION BIANPA',
#  '"ARPE"',
#  'CULTURAL Y SOCIAL P.A.L.S.',
#  'ASOCIACION AMIGOS DEL PERRO DE PASTOR ALEMÁN DE TENERIFE',
#  'ASOCIACION AMIGOS DE 4 PATAS',
#  'ASOCIACION DE AGILITY MAREA VERDE',
#  'CULTURAL THE KENNEL KLUB',
#  'ADASSA, EL PERRO OBEDIENTE',
#  'DÁLMATAS SOLIDARIOS',
#  'ECOLÓGICA "LOS REBUZNOS A. LÓPEZ"',
#  'LEYRE POR LOS PELUDOS',
#  'ASOCIACIÓN SANTUARIO JOSEFINA RIVERO Y SU PERRO WILLY']

# %%
pata= extraer_por_palabra(df, 'pata')

# %%
pata
# Out:
#           Nº CANARIO. C.I.F.                  DENOMINACION      AMBITO  \
# 41  G1/S1/11357-05/GC    NaN                  4 PATAS NEWS     INSULAR
# 75  G1/S1/17521-11/TF    NaN  ASOCIACION AMIGOS DE 4 PATAS  AUTONÓMICO
#
#                      SECCION               ACTIVIDADES FECHA CONSTITUCIÓN  \
# 41  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         15/12/2004
# 75  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS                NaN
#
#                    DIRECCION               PROVINCIA          ISLA  \
# 41  C/ ISLA DE BORNEO, Nº 36              Las Palmas  GRAN CANARIA
# 75          C/ ESCUELA Nº 11  Santa Cruz de Tenerife      TENERIFE
#
#                     MUNICIPIO  LOCALIDAD  CODIGO POSTAL   TELEFONO  \
# 41  SAN BARTOLOMÉ DE TIRAJANA        NaN        35109.0        NaN
# 75          PUERTO DE LA CRUZ        NaN        38340.0  607280519
#
#    DOMINIO INTERNET EMAIL
# 41              NaN   NaN
# 75              NaN   NaN

# %%
santu= extraer_por_palabra(df, 'santu')

# %%
santu
# Out:
#           Nº CANARIO.     C.I.F.  \
# 96  G1/S1/23572-18/TF  G76770502
#
#                                          DENOMINACION      AMBITO  \
# 96  ASOCIACIÓN SANTUARIO JOSEFINA RIVERO Y SU PERR...  AUTONÓMICO
#
#                      SECCION               ACTIVIDADES FECHA CONSTITUCIÓN  \
# 96  Sección 1 - Asociaciones  SOBRE ANIMALES Y PLANTAS         02/06/2018
#
#              DIRECCION               PROVINCIA      ISLA MUNICIPIO  LOCALIDAD  \
# 96  CALLE HONDURAS S/N  Santa Cruz de Tenerife  TENERIFE    GÜIMAR        NaN
#
#     CODIGO POSTAL TELEFONO DOMINIO INTERNET                              EMAIL
# 96        38500.0      NaN              NaN  santuariojosefinarivero@gmail.com

# %%
df_ok = pd.concat([df_ok , pata, santu], axis=0)

# %%
# Guardar DataFrame en un archivo de Excel
df_ok.to_excel('filtrado_canarias.xlsx', index=False)
