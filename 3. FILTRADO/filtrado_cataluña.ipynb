# %% [markdown]
# https://justicia.gencat.cat/ca/serveis/guia_d_entitats/#1

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("./DATOS INICIALES/asociaciones_cataluña.csv")
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_7968\2760563792.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("./DATOS INICIALES/asociaciones_cataluña.csv")

# %%
df
# Out:
#        codi_postal  fax tipus_entitat        cif  \
# 0             8521  NaN    Associació  No consta
# 1            17500  NaN    Associació  No consta
# 2             8348  NaN    Associació  No consta
# 3             8024  NaN    Associació  G58535220
# 4            17006  NaN    Associació  G17941261
# ...            ...  ...           ...        ...
# 84047         8960  NaN    Associació  No consta
# 84048        17451  NaN    Associació  No consta
# 84049         8396  NaN    Associació  G65752479
# 84050        17500  NaN    Associació  No consta
# 84051         8189  NaN    Associació  No consta
#
#                                              nom_entitat  \
# 0                         Associació TEA Vallès Oriental
# 1      Associació de Famílies d'Alumnes de l'Escola J...
# 2            Associació Comunitat Energètica del Maresme
# 3      Associació Juvenil Agrupament Escolta Roland P...
# 4      Associació DAGUA, ONG de Projectes Internacionals
# ...

# %%
classificacio = df['classificacio_general'].unique()
print(classificacio)
# Out:
# ['Salut' 'Ensenyament, formació i investigació'
#  "Ordenació de l'espai, ecologia i habitatge" 'Cultura'
#  'Foment i defensa dels drets cívics, socials i de la persona'
#  'Interessos de sectors econòmics, geogràfics o professionals'
#  'Assistencial i Cultural' 'Assistencial' '<sense classificacio>'
#  'Fins Científics' 'Cultural' 'Assistència social'
#  'Assistencial i Fins Científics' 'Assistència Social'
#  'Cultural, Assistencial i Fins Científics' 'Cultural i Docent'
#  'Cultural i Fins Científics' 'Docent' 'Docent i Fins Científics'
#  'Cultural, Assistencial i Docent' 'Assistencial i Docent'
#  'Cultural, Docent i Fins Científics'
#  'Assistencial, Docent i Fins Científics'
#  'Assistencia, Cultural, Docent i Fins Científics']

# %%
classificacio_no= ['Salut', 'Ensenyament, formació i investigació',
 'Cultura', 'Foment i defensa dels drets cívics, socials i de la persona',
 'Interessos de sectors econòmics, geogràfics o professionals',
 'Assistencial i Cultural', 'Assistencial',
 'Fins Científics' ,'Cultural', 'Assistència social',
 'Assistencial i Fins Científics', 'Assistència Social',
 'Cultural, Assistencial i Fins Científics', 'Cultural i Docent',
 'Cultural i Fins Científics' ,'Docent' ,'Docent i Fins Científics',
 'Cultural, Assistencial i Docent', 'Assistencial i Docent',
 'Cultural, Docent i Fins Científics',
 'Assistencial, Docent i Fins Científics',
 'Assistencia, Cultural, Docent i Fins Científics']

# %%
df = df[~df['classificacio_general'].isin(classificacio_no)]

# %%
df
# Out:
#        codi_postal        fax tipus_entitat        cif  \
# 2             8348        NaN    Associació  No consta
# 9            25210        NaN    Associació  No consta
# 14           43764        NaN    Associació  G55563548
# 15           25003        NaN    Associació  No consta
# 24            8600  938212875    Associació  G59552737
# ...            ...        ...           ...        ...
# 84030         8140        NaN    Associació  No consta
# 84032         8014        NaN    Associació  G60542073
# 84036         8013        NaN    Associació  No consta
# 84048        17451        NaN    Associació  No consta
# 84051         8189        NaN    Associació  No consta
#
#                                              nom_entitat  \
# 2            Associació Comunitat Energètica del Maresme
# 9                            Associació Gats de Guissona
# 14                            Associació Terres del Gaià
# 15                            Associació Ecoxarxa Segrià
# ...

# %%
df.columns
# Out:
# Index(['codi_postal', 'fax', 'tipus_entitat', 'cif', 'nom_entitat', 'adreca',
#        'nom_poblacio', 'nom_provincia', 'nom_comarca', 'classificacio_general',
#        'adreca_electronica', 'pagina_web', 'vinculacio_partit',
#        'classificacio_especifica', 'contingut_finalitats', 'finalitats2',
#        'finalitats3', 'finalitats4', 'finalitats5', 'finalitats6', 'fundadors',
#        'data_inscripcio', 'num_inscripcio', 'id_entitat', 'telefon'],
#       dtype='object')

# %%
classificacio2 = df['classificacio_especifica'].unique()
print(classificacio2)
# Out:
# ['ECOLOGIA, NATURALESA I MEDI AMBIENT' "PROTECCIÓ, DEFENSA D'ANIMALS"
#  "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|PROTECCIÓ"
#  "DEFENSA D'INTERESSOS PROPIS|PROPIETARIS D'URBANITZACIÓ|REIVINDICACIÓ"
#  nan
#  "AJUDA|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ, DEFENSA D'ANIMALS"
#  'ASSOCIACIONS A FAVOR DE' 'PROTECCIÓ' 'REIVINDICACIÓ|SOCIALS'
#  "ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|FOMENT D'ACTIVITATS"
#  "COOPERACIÓ, DESENVOLUPAMENT|FILOSOFIA|FINALITATS DIVERSES|FOMENT D'ACTIVITATS"
#  'ARTESANS, ARTESANIA'
#  "AMISTAT SOCIAL|PROTECCIÓ, DEFENSA D'ANIMALS|SOCIALS"
#  "AJUDA|CULTURALS DIVERSES|PREVENCIÓ|PROTECCIÓ, DEFENSA D'ANIMALS"
#  "CULTURALS DIVERSES|FOMENT D'ACTIVITATS|TEATRE" 'PREVENCIÓ|PROTECCIÓ'
#  'ECONOMIA|SOCIALS' 'ACTIVITATS JUVENILS'
#  "AJUDA|ECOLOGIA, NATURALESA I MEDI AMBIENT|PREVENCIÓ|PROTECCIÓ|PROTECCIÓ, DEFENSA D'ANIMALS"
#  "DEFENSA D'INTERESSOS PROPIS|PROPIETARIS EN GENERAL"
# ...

# %%
classificacio2_no= ['ECOLOGIA, NATURALESA I MEDI AMBIENT',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|PROTECCIÓ"
 "DEFENSA D'INTERESSOS PROPIS|PROPIETARIS D'URBANITZACIÓ|REIVINDICACIÓ",
 'REIVINDICACIÓ|SOCIALS',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|FOMENT D'ACTIVITATS",
 "COOPERACIÓ, DESENVOLUPAMENT|FILOSOFIA|FINALITATS DIVERSES|FOMENT D'ACTIVITATS",
 'ARTESANS, ARTESANIA',
 "CULTURALS DIVERSES|FOMENT D'ACTIVITATS|TEATRE", 'PREVENCIÓ|PROTECCIÓ',
 'ECONOMIA|SOCIALS', 'ACTIVITATS JUVENILS',
 "DEFENSA D'INTERESSOS PROPIS|PROPIETARIS EN GENERAL",
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 "FOMENT D'ACTIVITATS|RECREATIVES DIVERSES", 'CULTURALS DIVERSES',
 "FOMENT D'ACTIVITATS",
 "AFECCIONATS|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|TRADICIONS DIVERSES",
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS",
 'AJUDA|DONA, ACTIVITATS DE LA|FINALITATS DIVERSES|PREVENCIÓ|PROTECCIÓ|SOCIALS',
 "DEFENSA D'INTERESSOS PROPIS|REIVINDICACIÓ",
 "AMISTAT SOCIAL|DEFENSA D'INTERESSOS PROPIS|VEÏNS",
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESPORT',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PREVENCIÓ|PROTECCIÓ',
 "CULTURALS DIVERSES|FOMENT D'ACTIVITATS|SOCIALS",
 'PSICOLOGIA I COMPORTAMENT HUMÀ',
 'PROTECCIÓ CIVIL|VOLUNTARIAT',
 "CONSUMIDORS|DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PROPIETARIS EN GENERAL',
 'CULTURALS DIVERSES|FINALITATS DIVERSES|POLÍTICA|REIVINDICACIÓ',
 "AJUDA|AMISTAT SOCIAL|CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|VEÏNS",
 "PARES D'ALUMNES",
 "PROPIETARIS D'URBANITZACIÓ" ,'COORDINACIÓ|SOCIALS',
 'ESTRANGERS|IMMIGRACIÓ', 'CORALS, DANSAIRES|CULTURALS DIVERSES|MÚSICA',
 "DEFENSA D'INTERESSOS PROPIS",
 'ARTS PLÀSTIQUES|CULTURALS DIVERSES|FINALITATS DIVERSES|RECREATIVES DIVERSES',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ECONOMIA|ESTUDIS' 'ESTUDIS',
 'CORALS, DANSAIRES' "COORDINACIÓ|DEFENSA D'INTERESSOS PROPIS",
 'ESTUDIS|FINALITATS DIVERSES|SOCIALS',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PSICOLOGIA I COMPORTAMENT HUMÀ',
 "COOPERACIÓ, DESENVOLUPAMENT|FOMENT D'ACTIVITATS" 'REIVINDICACIÓ',
 "CONFESSIONALS, DOCTRINALS|FOMENT D'ACTIVITATS" 'DISCAPACITATS',
 "FOMENT D'ACTIVITATS|VEÏNS",
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|SOCIALS",
 'FINALITATS DIVERSES|VEÏNS',
 "CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|SOCIALS",
 'AJUDA|AMISTAT SOCIAL',
 'LITERATURA', 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ',
 "ASOC. D'ÀMBIT ESTATAL",
 'CULTURALS DIVERSES|ESPORT|GASTRONOMIA|MÚSICA|RECREATIVES DIVERSES|VEÏNS',
 'PROTECCIÓ CIVIL', 'AFECCIONATS' ,'JUVENILS', 'FINALITATS DIVERSES', 'MÚSICA',
 'PROPIETARIS EN GENERAL|VEÏNS' ,'RECREATIVES DIVERSES',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|VEÏNS' ,'PROPIETARIS EN GENERAL',
 'AJUDA' ,'COOPERACIÓ, DESENVOLUPAMENT', 'IMMIGRACIÓ',
 "DEFENSA D'INTERESSOS PROPIS|SOCIALS|VEÏNS",
 "AFECCIONATS|ASOC. D'ÀMBIT ESTATAL", 'COMERÇ, COMERCIANTS',
 'ASSOCIACIONS A FAVOR DE|REIVINDICACIÓ',
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT", 'ESPORT',
 'UTILITAT PÚBLICA GENERALITAT', 'VOLUNTARIAT' ,'TRADICIONS DIVERSES',
 "DEFENSA D'INTERESSOS PROPIS|FOMENT D'ACTIVITATS",
 'AMICS DE|CULTURALS DIVERSES', 'ESTRANGERS',
 'PRÀCTIQUES ORIENTALS',
 "DEFENSA D'INTERESSOS PROPIS|ESTUDIS",
 'ARTS PLÀSTIQUES|CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|NATURISTES',
 "CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESPORT|FOMENT D'ACTIVITATS|INVESTIGACIÓ, CIENTÍFIQUES",
 "CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|VEÏNS",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|TURISME', 'TEATRE',
 'AJUDA|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 'CULTURALS DIVERSES|RECREATIVES DIVERSES',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|GASTRONOMIA',
 "DEFENSA D'INTERESSOS PROPIS|VEÏNS" ,'PREVENCIÓ',
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|REIVINDICACIÓ",
 'CONSUMIDORS',
 'ASSOCIACIONS A FAVOR DE|CONSUMIDORS|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS",
 "AUDIOVISUALS|COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|ESTUDIS|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|TRADICIONS DIVERSES",
 "DEFENSA D'INTERESSOS PROPIS|FOMENT D'ACTIVITATS|VEÏNS",
 'COORDINACIÓ|PROTECCIÓ',
 'DONA, ACTIVITATS DE LA|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|NATURISTES',
 "FOMENT D'ACTIVITATS|GASTRONOMIA|VEÏNS",
 "CONSUMIDORS|DEFENSA D'INTERESSOS PROPIS", 'POLÍTICA', 'ESTUDIANTS',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|PROPIETARIS D'URBANITZACIÓ",
 "DEFENSA D'INTERESSOS PROPIS|PROFESSIONALS",
 'PROFESSIONALS',
 "PROPIETARIS D'URBANITZACIÓ|VEÏNS",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES', 'SANITAT',
 "ASOC. D'ÀMBIT ESTATAL|PROTECCIÓ", 'SOCIALS|VEÏNS',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|PROPIETARIS EN GENERAL",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS', 'GASTRONOMIA',
 'AJUDA|DISCAPACITATS' ,'COORDINACIÓ',
 'AMISTAT SOCIAL|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 'AMICS DE' ,'FOTOGRAFIA',
 'PREVENCIÓ|VOLUNTARIAT', 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PREVENCIÓ',
 'AMICS DE|ECOLOGIA, NATURALESA I MEDI AMBIENT' ,'COMUNICACIONS',
 'CULTURALS DIVERSES|POLÍTICA' ,'CULTURALS DIVERSES|TRADICIONS DIVERSES',
 "AFECCIONATS|ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT",
 "ASOC. D'ÀMBIT ESTATAL|FOMENT D'ACTIVITATS|PROTECCIÓ",'ESTUDIS|PROTECCIÓ',
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PROFESSIONALS',
 'ASSOCIACIONS A FAVOR DE|FINALITATS DIVERSES',
 'AFECCIONATS|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 'COORDINACIÓ|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 "ASSOCIACIONS A FAVOR DE|COOPERACIÓ, DESENVOLUPAMENT|ECOLOGIA, NATURALESA I MEDI AMBIENT|ECONOMIA|FOMENT D'ACTIVITATS|NATURISTES|SOCIALS",
 'CULTURALS DIVERSES|FINALITATS DIVERSES',
 'AFECCIONATS|NATURISTES|PROTECCIÓ',
 'UTILITAT PUBLICA ESTATAL|UTILITAT PÚBLICA GENERALITAT',
 'POLÍTICA|REIVINDICACIÓ' ,'FOLKLORE' ,'SOCIALS' ,'CULTURALS DIVERSES|TEATRE',
 'CULTURALS DIVERSES|LITERATURA',
 "PROPIETARIS D'URBANITZACIÓ|PROPIETARIS EN GENERAL|VEÏNS",
 'ALUMNES I EXALUMNES' 'ECOLOGIA, NATURALESA I MEDI AMBIENT|REIVINDICACIÓ',
 'ASSOCIACIONS A FAVOR DE|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 'ALUMNES (LODE)', "FINALITATS DIVERSES|FOMENT D'ACTIVITATS",
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ',
 'AFECCIONATS|AJUDA|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ',
 "ASOC. D'ÀMBIT ESTATAL|ESPORT|PROFESSIONALS",
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|MÚSICA|NATURISTES',
 'REIVINDICACIÓ|SANITAT', 'VETERANS',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|VEÏNS' ,'FUTBOL',
 'FINALITATS DIVERSES|SOCIALS',
 'COOPERACIÓ, DESENVOLUPAMENT|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 'RADIOAFECCIONATS',
 "DEFENSA D'INTERESSOS PROPIS|GASTRONOMIA",
 "CLUBS DE FUMADORS|CONSUMIDORS DE CÀNNABIS|DEFENSA D'INTERESSOS PROPIS|MEDICINA",
 'TERCERA EDAT, JUBILATS',
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|PROTECCIÓ",
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROPIETARIS EN GENERAL",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ETNOGRAFIA|PROTECCIÓ',
 'AJUDA|SOCIALS' "ASOC. D'ÀMBIT ESTATAL|CULTURALS DIVERSES|SOCIALS",
 'PENYES' 'ECOLOGIA, NATURALESA I MEDI AMBIENT|SOCIALS',
 'AMICS DE|PROTECCIÓ',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|MÚSICA",
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS",
 "ESPORT|PARES D'ALUMNES",
 "AMICS DE|CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|ESTRANGERS|IMMIGRACIÓ|SOCIALS|TRADICIONS DIVERSES",
 "AFECCIONATS|CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|ESPORT",
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROFESSIONALS|PROTECCIÓ",
 'CULTURALS DIVERSES|MÚSICA|TEATRE' 'AFECCIONATS|NATURISTES',
 'AMICS DE|PROPIETARIS EN GENERAL|VEÏNS',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|SANITAT',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|JUVENILS',
 "ASOC. D'ÀMBIT ESTATAL|CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT",
 "CLUBS DE FUMADORS|CONSUMIDORS DE CÀNNABIS|DEFENSA D'INTERESSOS PROPIS",
 "DEFENSA D'INTERESSOS PROPIS|RECREATIVES DIVERSES" 'NATURISTES',
 "COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS",
 'AJUDA|COOPERACIÓ, DESENVOLUPAMENT' "ESTUDIS|FOMENT D'ACTIVITATS",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|PREVENCIÓ|PROTECCIÓ',
 'ALUMNES I EXALUMNES|CULTURALS DIVERSES',
 "ESPORT|FOMENT D'ACTIVITATS|GASTRONOMIA",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ CIVIL',
 'CULTURALS DIVERSES|NATURISTES' ,"DEFENSA D'INTERESSOS PROPIS|ECONOMIA",
 "AMICS DE|DEFENSA D'INTERESSOS PROPIS",
 'CONSUMIDORS|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|INVESTIGACIÓ, CIENTÍFIQUES',
 'DONA, ACTIVITATS DE LA' "DEFENSA D'INTERESSOS PROPIS|ESPORT",
 'CULTURALS DIVERSES|JUVENILS|TEATRE',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|FOMENT D'ACTIVITATS",
 'IMMIGRACIÓ|TEATRE',
 "DEFENSA D'INTERESSOS PROPIS|PROPIETARIS EN GENERAL|VEÏNS",
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|POLÍTICA',
 "DEFENSA D'INTERESSOS PROPIS|TURISME",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|RECREATIVES DIVERSES',
 "AMICS DE|PROPIETARIS D'URBANITZACIÓ",
 "AFECCIONATS|AMICS DE|COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|SOCIALS",
 'INVESTIGACIÓ, CIENTÍFIQUES',
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS',
 "ASOC. D'ÀMBIT ESTATAL|PROFESSIONALS" ,'CLUBS DE FUMADORS', 'AUDIOVISUALS',
 'ASSOCIACIONS A FAVOR DE|TRADICIONS DIVERSES',
 'COOPERACIÓ, DESENVOLUPAMENT|IMMIGRACIÓ',
 "FOMENT D'ACTIVITATS|PROTECCIÓ",
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|ESPORT|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|NATURISTES|RECREATIVES DIVERSES",
 'FINALITATS DIVERSES|PROTECCIÓ',
 "CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS",
 "CULTURALS DIVERSES|FOMENT D'ACTIVITATS|VEÏNS",
 'COOPERACIÓ, DESENVOLUPAMENT|SANITAT', 'AJUDA|ESTUDIS|PROFESSIONALS',
 'AMICS DE|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ',
 'ESPORT|VETERANS', 'COMERÇ, COMERCIANTS|PROFESSIONALS',
 "DEFENSA D'INTERESSOS PROPIS|DONA, ACTIVITATS DE LA",
 'UTILITAT PÚBLICA GENERALITAT|VETERANS',
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|JUVENILS",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ECONOMIA' ,'CULTURALS DIVERSES|VEÏNS',
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|ECONOMIA|SOCIALS',
 "DEFENSA D'INTERESSOS PROPIS|PROPIETARIS D'URBANITZACIÓ",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ETNOGRAFIA',
 'AFECCIONATS|CULTURALS DIVERSES|ESPORT',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|REIVINDICACIÓ",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|UTILITAT PUBLICA ESTATAL',
 "ASOC. D'ÀMBIT ESTATAL|PROFESSIONALS|PROTECCIÓ",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|UTILITAT PÚBLICA GENERALITAT',
 "AMICS DE|PARES D'ALUMNES" "PARES D'ALUMNES (LODE)",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|IMMIGRACIÓ',
 'ESTUDIS|PRÀCTIQUES ORIENTALS', 'DISCAPACITATS|FINALITATS DIVERSES',
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESPORT|PROFESSIONALS",
 'PRÀCTIQUES ORIENTALS|PSICOLOGIA I COMPORTAMENT HUMÀ',
 'ESTUDIS|NATURISTES',
 "CULTURALS DIVERSES|ESPORT|FOMENT D'ACTIVITATS|FUTBOL|PENYES|RECREATIVES DIVERSES|SOCIALS",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIANTS',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|PROTECCIÓ',
 "ESPORT|FOMENT D'ACTIVITATS" 'AMICS DE|FINALITATS DIVERSES',
 'AJUDA|IMMIGRACIÓ' "CULTURALS DIVERSES|FOLKLORE|FOMENT D'ACTIVITATS",
 'AUDIOVISUALS|COOPERACIÓ, DESENVOLUPAMENT|PROFESSIONALS',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PREVENCIÓ|PROTECCIÓ CIVIL',
 "CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|FINALITATS DIVERSES|FOMENT D'ACTIVITATS",
 "COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES|DONA, ACTIVITATS DE LA|ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|NATURISTES|SOCIALS|TRADICIONS DIVERSES",
 "CULTURALS DIVERSES|FOMENT D'ACTIVITATS" 'CULTURALS DIVERSES|MÚSICA',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PRÀCTIQUES ORIENTALS',
 "DEFENSA D'INTERESSOS PROPIS|REIVINDICACIÓ|VEÏNS",
 'AJUDA|COOPERACIÓ, DESENVOLUPAMENT|ECOLOGIA, NATURALESA I MEDI AMBIENT|SOCIALS|VOLUNTARIAT',
 'CASALS I ATENEUS|CULTURALS DIVERSES|RECREATIVES DIVERSES',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|MUNDIALISTES',
 'ARTESANS, ARTESANIA|TEATRE', 'AFECCIONATS|PREVENCIÓ',
 'AMISTAT SOCIAL|SOCIALS',
 'ARTESANS, ARTESANIA|ECOLOGIA, NATURALESA I MEDI AMBIENT|SOCIALS',
 'PROFESSIONALS|PROTECCIÓ',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|INVESTIGACIÓ, CIENTÍFIQUES',
 'CONSUMIDORS|ECOLOGIA, NATURALESA I MEDI AMBIENT|GASTRONOMIA',
 'FINALITATS DIVERSES|MÚSICA',
 "CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|ESPORT|RECREATIVES DIVERSES|VEÏNS",
 'PROTECCIÓ DE MENORS',
 "FINALITATS DIVERSES|FOMENT D'ACTIVITATS|REIVINDICACIÓ|SOCIALS",
 "CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|PROPIETARIS EN GENERAL",
 'AFECCIONATS|ASSOCIACIONS A FAVOR DE|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 "PARES D'ALUMNES|PARES D'ALUMNES (LODE)",
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|NATURISTES",
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|RECREATIVES DIVERSES',
 "ACTIVITATS JUVENILS|COOPERACIÓ, DESENVOLUPAMENT|FOMENT D'ACTIVITATS|PREVENCIÓ|PROTECCIÓ|REIVINDICACIÓ",
 'COMUNICACIONS|SOCIALS',
 "AFECCIONATS|ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS",
 "COOPERACIÓ, DESENVOLUPAMENT|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|FOMENT D'ACTIVITATS|SOCIALS",
 'ARTS PLÀSTIQUES|FINALITATS DIVERSES',
 "ASSOCIACIONS A FAVOR DE|CULTURALS DIVERSES|FOMENT D'ACTIVITATS",
 "ASOC. D'ÀMBIT ESTATAL|PRÀCTIQUES ORIENTALS",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ESPORT','ESTUDIS|REIVINDICACIÓ',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|NATURISTES",
 'AJUDA|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROFESSIONALS',
 'ESPORT|FINALITATS DIVERSES',
 'ARTESANS, ARTESANIA|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 "AJUDA|DEFENSA D'INTERESSOS PROPIS" ,'ESTUDIS|PROFESSIONALS',
 "612|ASOC. D'ÀMBIT ESTATAL|PREVENCIÓ",
 'ASSOCIACIONS A FAVOR DE|REIVINDICACIÓ|SOCIALS',
 'COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES|FINALITATS DIVERSES',
 "ARTESANS, ARTESANIA|ARTS PLÀSTIQUES|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS",
 "ASSOCIACIONS A FAVOR DE|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|PROTECCIÓ|REIVINDICACIÓ",
 'TEATRE|TERCERA EDAT, JUBILATS',
 'PROPIETARIS EN GENERAL|REIVINDICACIÓ',
 "DEFENSA D'INTERESSOS PROPIS|PROPIETARIS EN GENERAL|REIVINDICACIÓ|VEÏNS",
 'DONA, ACTIVITATS DE LA|ESTRANGERS',
 'ASSOCIACIONS A FAVOR DE|COORDINACIÓ|ECONOMIA|FINALITATS DIVERSES|PROTECCIÓ',
 'COMERÇ, COMERCIANTS|ECOLOGIA, NATURALESA I MEDI AMBIENT|TURISME',
 'CINEMA',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|ESPORT|FOMENT D'ACTIVITATS|NATURISTES|SANITAT|SOCIALS",
 'CONSUMIDORS DE CÀNNABIS|ESTUDIS',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|ESPORT|FOMENT D'ACTIVITATS",
 'PSICOLOGIA I COMPORTAMENT HUMÀ|SANITAT',
 'ASSOCIACIONS A FAVOR DE|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROFESSIONALS',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|PROTECCIÓ|SOCIALS",
 'CORALS, DANSAIRES|CULTURALS DIVERSES', 'AMICS DE|ASSOCIACIONS A FAVOR DE',
 'CULTURALS DIVERSES|ESPORT|RECREATIVES DIVERSES|SOCIALS|VEÏNS',
 'ESTRANGERS|IMMIGRACIÓ|SOCIALS' ,'JUVENILS|MÚSICA',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PREVENCIÓ|REIVINDICACIÓ',
 'AMICS DE|PROPIETARIS EN GENERAL',
 "FOMENT D'ACTIVITATS|INVESTIGACIÓ, CIENTÍFIQUES|NATURISTES|PSICOLOGIA I COMPORTAMENT HUMÀ|SOCIALS",
 'CORALS, DANSAIRES|MÚSICA', 'DISCAPACITATS|ESPORT',
 'COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|ECONOMIA|FINALITATS DIVERSES',
 "ASSOCIACIONS A FAVOR DE|CULTURALS DIVERSES|FOMENT D'ACTIVITATS|RECREATIVES DIVERSES",
 "CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|RECREATIVES DIVERSES|VEÏNS",
 'AFECCIONATS|PROPIETARIS EN GENERAL',
 "ASOC. D'ÀMBIT ESTATAL|INVESTIGACIÓ, CIENTÍFIQUES",
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|RECREATIVES DIVERSES",
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|INVESTIGACIÓ, CIENTÍFIQUES',
 'AMICS DE|VEÏNS', "DISCAPACITATS|FOMENT D'ACTIVITATS",
 'PROTECCIÓ|REIVINDICACIÓ' ,'PREVENCIÓ|SANITAT' ,'Assistencial',
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|NATURISTES',
 'PROTECCIÓ|VOLUNTARIAT',
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|PREVENCIÓ|PROTECCIÓ",
 "ASOC. D'ÀMBIT ESTATAL|PROPIETARIS D'URBANITZACIÓ",
 'CONSUMIDORS DE CÀNNABIS',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ETNOGRAFIA|REIVINDICACIÓ',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|POLÍTICA',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|VOLUNTARIAT',
 'COMERÇ, COMERCIANTS|PROPIETARIS EN GENERAL|VEÏNS',
 'COORDINACIÓ|INVESTIGACIÓ, CIENTÍFIQUES|PROFESSIONALS',
 "AJUDA|FOMENT D'ACTIVITATS" ,'FOLKLORE|MÚSICA',
 "ASOC. D'ÀMBIT ESTATAL|DEFENSA D'INTERESSOS PROPIS",
 'CULTURALS DIVERSES|ESPORT',
 'ESTUDIS|PROTECCIÓ|UTILITAT PUBLICA ESTATAL',
 'CULTURALS DIVERSES|ETNOGRAFIA' "DEFENSA D'INTERESSOS PROPIS|IMMIGRACIÓ",
 'CONFESSIONALS, DOCTRINALS', "DEFENSA D'INTERESSOS PROPIS|ESTUDIANTS",
 'ASSOCIACIONS A FAVOR DE|SOCIALS',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ|REIVINDICACIÓ',
 'COOPERACIÓ, DESENVOLUPAMENT|GASTRONOMIA', 'Cultural',
 "DEFENSA D'INTERESSOS PROPIS|INVESTIGACIÓ, CIENTÍFIQUES|PROFESSIONALS",
 "DEFENSA D'INTERESSOS PROPIS|PROPIETARIS EN GENERAL|REIVINDICACIÓ",
 'ROMEUS I COLLES',
 'FINALITATS DIVERSES|PROPIETARIS EN GENERAL' ,'AJUDA|PROTECCIÓ DE MENORS',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|TRADICIONS DIVERSES',
 "PROPIETARIS D'URBANITZACIÓ|RECREATIVES DIVERSES",
 "COOPERACIÓ, DESENVOLUPAMENT|COORDINACIÓ|DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|PROFESSIONALS",
 "ASOC. D'ÀMBIT ESTATAL|PROPIETARIS EN GENERAL",
 'AMISTAT SOCIAL|COOPERACIÓ, DESENVOLUPAMENT|IMMIGRACIÓ',
 'ASSOCIACIONS A FAVOR DE|VEÏNS' 'CULTURALS DIVERSES|ESTRANGERS',
 "DEFENSA D'INTERESSOS PROPIS|FINALITATS DIVERSES" ,'AJUDA|NATURISTES',
 "CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|ECONOMIA|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|SOCIALS",
 'MEDICINA',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|NATURISTES',
 'AJUDA|UTILITAT PÚBLICA GENERALITAT', 'ASSOCIACIONS PRO|DISCAPACITATS',
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|ECONOMIA|PROTECCIÓ',
 "COOPERACIÓ, DESENVOLUPAMENT|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS",
 'FINALITATS DIVERSES|IMMIGRACIÓ',
 "CULTURALS DIVERSES|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|VOLUNTARIAT",
 "AFECCIONATS|ESTUDIANTS|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|RECREATIVES DIVERSES|SOCIALS",
 'AFECCIONATS|ECOLOGIA, NATURALESA I MEDI AMBIENT|PREVENCIÓ|PROTECCIÓ|VOLUNTARIAT',
 "CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|PROPIETARIS EN GENERAL|RECREATIVES DIVERSES|VEÏNS",
 "CULTURALS DIVERSES|DONA, ACTIVITATS DE LA|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS",
 "CULTURALS DIVERSES|ESTUDIS|FOMENT D'ACTIVITATS",
 'SOCIALS|TERCERA EDAT, JUBILATS',
 'COMUNICACIONS|COOPERACIÓ, DESENVOLUPAMENT|ESTUDIS',
 'PREVENCIÓ|PROTECCIÓ CIVIL',
 "ASSOCIACIONS A FAVOR DE|CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|GASTRONOMIA|NATURISTES",
 'CULTURALS DIVERSES|IMMIGRACIÓ',
 "COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|REIVINDICACIÓ|SOCIALS",
 "ASOC. D'ÀMBIT ESTATAL|ESTUDIS" 'CULTURALS DIVERSES|SOCIALS',
 'AFECCIONATS|ESPORT' ,'COMERÇ, COMERCIANTS|TURISME',
 "DEFENSA D'INTERESSOS PROPIS|FOMENT D'ACTIVITATS|PROPIETARIS EN GENERAL|VEÏNS",
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|GASTRONOMIA",
 "ASOC. D'ÀMBIT ESTATAL|PREVENCIÓ",
 'ARTESANS, ARTESANIA|ECONOMIA|PROFESSIONALS'
 "AMICS DE|CULTURALS DIVERSES|FOMENT D'ACTIVITATS",
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|FOMENT D'ACTIVITATS",
 'ASSOCIACIONS A FAVOR DE|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|IMMIGRACIÓ",
 'FINALITATS DIVERSES|REIVINDICACIÓ',
 'AMICS DE|CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|MEDICINA',
 "AJUDA|DEFENSA D'INTERESSOS PROPIS|PROPIETARIS D'URBANITZACIÓ|VEÏNS",
 "CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|REIVINDICACIÓ",
 "ASOC. D'ÀMBIT ESTATAL|COORDINACIÓ|FOMENT D'ACTIVITATS",
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|FOMENT D'ACTIVITATS",
 'CULTURALS DIVERSES|RECREATIVES DIVERSES|VEÏNS',
 'AJUDA|DONA, ACTIVITATS DE LA' 'ALUMNES I EXALUMNES|PROFESSIONALS',
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|MEDICINA",
 "CULTURALS DIVERSES|FOMENT D'ACTIVITATS|RECREATIVES DIVERSES",
 'ARTS PLÀSTIQUES',
 "AMICS DE|ASSOCIACIONS A FAVOR DE|CONFESSIONALS, DOCTRINALS|COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|SOCIALS|TRADICIONS DIVERSES",
 "COMERÇ, COMERCIANTS|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS",
 "CULTURALS DIVERSES|FINALITATS DIVERSES|FOMENT D'ACTIVITATS",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|FOTOGRAFIA',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PROPIETARIS EN GENERAL|PROTECCIÓ',
 'PROFESSIONALS|TRADICIONS DIVERSES',
 'COMERÇ, COMERCIANTS|CULTURALS DIVERSES', 'NATURISTES|PROTECCIÓ',
 'SOCIALS|UTILITAT PÚBLICA GENERALITAT',
 "CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|FOMENT D'ACTIVITATS|RECREATIVES DIVERSES|VEÏNS",
 'MÚSICA|TEATRE',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|FINALITATS DIVERSES',
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|SOCIALS",
 'AMICS DE|ECOLOGIA, NATURALESA I MEDI AMBIENT|UTILITAT PUBLICA ESTATAL',
 'PREVENCIÓ|PROFESSIONALS|PROTECCIÓ',
 'COMERÇ, COMERCIANTS|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 'AJUDA|CULTURALS DIVERSES' "PROTECCIÓ, DEFENSA D'ANIMALS|SANITAT",
 "CONSUMIDORS|ECOLOGIA, NATURALESA I MEDI AMBIENT|ECONOMIA|FOMENT D'ACTIVITATS",
 'AJUDA|PROTECCIÓ CIVIL' "DEFENSA D'INTERESSOS PROPIS|PREVENCIÓ",
 'COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES',
 'ASSOCIACIONS A FAVOR DE|COMERÇ, COMERCIANTS|CONSUMIDORS|ECOLOGIA, NATURALESA I MEDI AMBIENT',
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|SOCIALS",
 'AJUDA|COMUNICACIONS|COOPERACIÓ, DESENVOLUPAMENT',
 'AJUDA|DISCAPACITATS|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ',
 "DEFENSA D'INTERESSOS PROPIS|DISCAPACITATS",
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROFESSIONALS",
 'TURISME', 'ASSOCIACIONS A FAVOR DE|POLÍTICA',
 'COMERÇ, COMERCIANTS|ECOLOGIA, NATURALESA I MEDI AMBIENT|ECONOMIA',
 "AMICS DE|ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT",
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|UTILITAT PUBLICA ESTATAL",
 "CULTURALS DIVERSES|ESPORT|PROPIETARIS D'URBANITZACIÓ",
 'COOPERACIÓ, DESENVOLUPAMENT|TURISME' ,'ECONOMIA|PROPIETARIS EN GENERAL',
 'AFECCIONATS|CONSUMIDORS DE CÀNNABIS', "FOMENT D'ACTIVITATS|MÚSICA",
 'DISCAPACITATS|UTILITAT PÚBLICA GENERALITAT',
 "ESPORT|FOMENT D'ACTIVITATS|SOCIALS",
 "ASOC. D'ÀMBIT ESTATAL|RECREATIVES DIVERSES",
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|FOMENT D'ACTIVITATS|JUVENILS",
 'CULTURALS DIVERSES|ETNOGRAFIA|FOLKLORE|MÚSICA',
 "DEFENSA D'INTERESSOS PROPIS|PROTECCIÓ",
 "ACTIVITATS JUVENILS|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIANTS|ESTUDIS|FOMENT D'ACTIVITATS|INVESTIGACIÓ, CIENTÍFIQUES|RECREATIVES DIVERSES",
 'ESPORT|RECREATIVES DIVERSES',
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|REIVINDICACIÓ",
 'COOPERACIÓ, DESENVOLUPAMENT|ECOLOGIA, NATURALESA I MEDI AMBIENT|SOCIALS',
 "CONFESSIONALS, DOCTRINALS|CORALS, DANSAIRES|CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|FINALITATS DIVERSES|MÚSICA",
 "ASSOCIACIONS A FAVOR DE|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS",
 "CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|DONA, ACTIVITATS DE LA|ECONOMIA|FOMENT D'ACTIVITATS|RECREATIVES DIVERSES|REIVINDICACIÓ|VOLUNTARIAT",
 'ESPORT|NATURISTES',
 'CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|TRADICIONS DIVERSES',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|SOCIALS',
 'DONA, ACTIVITATS DE LA|IMMIGRACIÓ',
 "COOPERACIÓ, DESENVOLUPAMENT|FOMENT D'ACTIVITATS|REIVINDICACIÓ",
 "ASOC. D'ÀMBIT ESTATAL|ESTUDIS|PROTECCIÓ",
 'AFECCIONATS|CORALS, DANSAIRES|CULTURALS DIVERSES|FOLKLORE|MÚSICA|RECREATIVES DIVERSES',
 "DEFENSA D'INTERESSOS PROPIS|PROPIETARIS D'URBANITZACIÓ|VEÏNS",
 "ASOC. D'ÀMBIT ESTATAL|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|PROFESSIONALS",
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|ESTUDIS|FOMENT D'ACTIVITATS|NATURISTES|PRÀCTIQUES ORIENTALS|SANITAT",
 'AFECCIONATS|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ',
 "FOMENT D'ACTIVITATS|TERCERA EDAT, JUBILATS",
 "AFECCIONATS|ECOLOGIA, NATURALESA I MEDI AMBIENT|ESPORT|FINALITATS DIVERSES|FOMENT D'ACTIVITATS",
 "ASOC. D'ÀMBIT ESTATAL|MEDICINA",
 "COMERÇ, COMERCIANTS|DEFENSA D'INTERESSOS PROPIS|FOMENT D'ACTIVITATS",
 'ECONOMIA' ,"CULTURALS DIVERSES|FOMENT D'ACTIVITATS|IMMIGRACIÓ|LITERATURA",
 "ASSOCIACIONS A FAVOR DE|CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|FOMENT D'ACTIVITATS",
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|MEDICINA|NATURISTES',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|VOLUNTARIAT",
 'PREVENCIÓ|PROTECCIÓ CIVIL|VOLUNTARIAT', 'AMICS DE|REIVINDICACIÓ',
 "CULTURALS DIVERSES|DEFENSA D'INTERESSOS PROPIS|ESPORT|PROPIETARIS EN GENERAL",
 "DEFENSA D'INTERESSOS PROPIS|ESPORT|PROPIETARIS EN GENERAL",
 'REIVINDICACIÓ|VEÏNS',
 "COOPERACIÓ, DESENVOLUPAMENT|DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|SOCIALS",
 'COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|RECREATIVES DIVERSES',
 'COOPERACIÓ, DESENVOLUPAMENT|SOCIALS',
 'AJUDA|COMERÇ, COMERCIANTS|ECOLOGIA, NATURALESA I MEDI AMBIENT|PROFESSIONALS',
 "CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|TRADICIONS DIVERSES",
 'PREVENCIÓ|REIVINDICACIÓ',
 "DEFENSA D'INTERESSOS PROPIS|PROTECCIÓ CIVIL",
 "AFECCIONATS|FOMENT D'ACTIVITATS|SOCIALS",
 'GASTRONOMIA|RECREATIVES DIVERSES',
 'ASSOCIACIONS A FAVOR DE|CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|INVESTIGACIÓ, CIENTÍFIQUES|SOCIALS',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|NATURISTES|PROTECCIÓ',
 "ECOLOGIA, NATURALESA I MEDI AMBIENT|FOMENT D'ACTIVITATS|NATURISTES|SOCIALS",
 'ASSOCIACIONS A FAVOR DE|ECOLOGIA, NATURALESA I MEDI AMBIENT|GASTRONOMIA|TURISME',
 "DEFENSA D'INTERESSOS PROPIS|ECONOMIA|FOMENT D'ACTIVITATS|PROFESSIONALS",
 'ESTUDIS|PREVENCIÓ' ,'COORDINACIÓ|PROFESSIONALS' ,'HUMOR',
 'ASSOCIACIONS A FAVOR DE|COMUNICACIONS', 'ASSOCIACIONS A FAVOR DE|MÚSICA',
 'CULTURALS DIVERSES|PROTECCIÓ',
 'COOPERACIÓ, DESENVOLUPAMENT|CULTURALS DIVERSES|ECOLOGIA, NATURALESA I MEDI AMBIENT|FINALITATS DIVERSES|PRÀCTIQUES ORIENTALS',
 'ECOLOGIA, NATURALESA I MEDI AMBIENT|PROTECCIÓ|RECREATIVES DIVERSES',
 "DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|INVESTIGACIÓ, CIENTÍFIQUES",
 "ASOC. D'ÀMBIT ESTATAL|DEFENSA D'INTERESSOS PROPIS|ECOLOGIA, NATURALESA I MEDI AMBIENT|ECONOMIA"]

# %%
df = df[~df['classificacio_especifica'].isin(classificacio2_no)]

# %%
df
# Out:
#        codi_postal        fax tipus_entitat        cif  \
# 9            25210        NaN    Associació  No consta
# 14           43764        NaN    Associació  G55563548
# 24            8600  938212875    Associació  G59552737
# 26            8902        NaN    Associació  G63483358
# 38            8173        NaN    Associació  G63017149
# ...            ...        ...           ...        ...
# 84019         8003        NaN    Associació  No consta
# 84029        43596        NaN    Associació  No consta
# 84030         8140        NaN    Associació  No consta
# 84032         8014        NaN    Associació  G60542073
# 84048        17451        NaN    Associació  No consta
#
#                                              nom_entitat  \
# 9                            Associació Gats de Guissona
# 14                            Associació Terres del Gaià
# 24     Associació de Propietaris Forestals Afectats p...
# 26                            Associació Alto al Mobbing
# ...

# %% [markdown]
# FUNCIONES:

# %%
# Crea un df con los registros en los que aparece el nombre que le digo
def extraer_por_palabra(df, palabra):
    df_palabra = df[df['nom_entitat'].str.lower().str.contains(palabra.lower())]
    return df_palabra

# %%
def restar_df(df_minuendo, df_sustraendo):
    df_diferencia = df_minuendo.merge(df_sustraendo, how='outer', indicator=True)
    df_diferencia = df_diferencia.loc[df_diferencia['_merge'] == 'left_only'].drop(columns='_merge')
    return df_diferencia

# %%
def eliminar_filas_listanegra(df, listanegra):
    # Crea una Serie booleana que indica si cada fila contiene alguna palabra de la lista negra
    mascara = df['nom_entitat'].str.contains('|'.join(listanegra), case=False)
    # Elimina las filas que cumplen la condición anterior
    df = df[~mascara]
    return df

# %%
# Creo df_ok para introducir en el los registros que me interesan y que en df se me vayan quedando los que no
df_ok= extraer_por_palabra(df,'animal')

# %%
df_ok
# Out:
#        codi_postal  fax tipus_entitat        cif  \
# 52            8720  NaN    Associació  G66843608
# 66           25739  NaN    Associació  No consta
# 385           8811  NaN    Associació  G66665613
# 704           8329  NaN    Associació  G62241419
# 865          17004  NaN    Associació  G55365449
# ...            ...  ...           ...        ...
# 82956        17450  NaN    Associació  No consta
# 83373        17497  NaN    Associació  No consta
# 83707         8096  NaN    Associació  No consta
# 83733        25280  NaN    Associació  G25742115
# 84029        43596  NaN    Associació  No consta
#
#                                              nom_entitat  \
# 52     Voluntacaad-Associació de Voluntaris del Centr...
# 66                  Associació Mon Animal del Colldelrat
# 385    Associació Amics dels Animals de Canyelles Hue...
# 704    Associació Teià per la Defensa dels Animals i ...
# 865            ASSOCIACIÓ PROJECTE LOLA, BENESTAR ANIMAL
# ...

# %%
df= restar_df(df, df_ok)

# %%
protect= extraer_por_palabra(df,'protect')
protect
# Out:
#       codi_postal        fax tipus_entitat        cif  \
# 511         17400        NaN    Associació  No consta
# 692          8290        NaN    Associació  G65499782
# 954          8191        NaN    Associació  G65208514
# 1086        43830        NaN    Associació  No consta
# 1260         8191        NaN    Associació  G64806128
# 1917        17220        NaN    Associació  G17999384
# 2102        17412        NaN    Associació  G55194450
# 2196         8223        NaN    Associació  G01609569
# 2438         8750        NaN    Associació  No consta
# 3490         8339  937508705    Associació  No consta
# 3495        43882        NaN    Associació  No consta
# 4039        43580        NaN    Associació  G55666507
# 4232         8916        NaN    Associació  No consta
# 4595        17246        NaN    Associació  No consta
# 5830        17700        NaN    Associació  G55249213
# 6204        17257        NaN    Associació  G17542861
# ...

# %%
df_ok = pd.concat([df_ok , protect], axis=0)

# %%
df= restar_df(df, protect)

# %%
felin= extraer_por_palabra(df,'felin')
felin
# Out:
#       codi_postal  fax tipus_entitat        cif  \
# 68           8784  NaN    Associació  G72818594
# 492         25300  NaN    Associació  G25741406
# 599         43540  NaN    Associació  No consta
# 748         43720  NaN    Associació  No consta
# 973         43007  NaN    Associació  No consta
# 2762         8736  NaN    Associació  No consta
# 3604        43004  NaN     Federació  No consta
# 3958         8041  NaN    Associació  G66186065
# 3973        17404  NaN    Associació  No consta
# 4206         8370  NaN    Associació  No consta
# 6973        17410  NaN    Associació  G55270268
# 7035         8018  NaN    Associació  No consta
#
#                                      nom_entitat  \
# 68                       Associació Piera Felina
# 492               Associació La Barretina Felina
# 599                     Associació Ràpita Felina
# 748                      Asociación Felina Arboç
# 973                    Associació Tarraco Felina
# ...

# %%
df_ok = pd.concat([df_ok , felin], axis=0)
df= restar_df(df, felin)

# %%
gats= extraer_por_palabra(df,'gats')
gats
# Out:
#       codi_postal  fax tipus_entitat        cif  \
# 0           25210  NaN    Associació  No consta
# 5           17490  NaN    Associació  G72544315
# 13           8880  NaN    Associació  G67002048
# 18           8590  NaN    Associació  No consta
# 35          43712  NaN    Associació  G72814601
# ...           ...  ...           ...        ...
# 6933         8450  NaN    Associació  No consta
# 6981         8860  NaN    Associació  No consta
# 6998         8754  NaN    Associació  No consta
# 7083         8902  NaN    Associació  G66391715
# 7230         8917  NaN    Associació  G63708838
#
#                                  nom_entitat  \
# 0                Associació Gats de Guissona
# 5                   Assocació Gats de Llançà
# 13        Associació Gats de Carrer Cubelles
# 18                        Associació Somgats
# 35    Associació Gats de Llorenç del Penedès
# ...                                      ...
# 6933  Associació Amants dels Gats de Llinars
# ...

# %%
df_ok = pd.concat([df_ok , gats], axis=0)
df= restar_df(df, gats)

# %%
listanegra= ['cult','juv','fam','jov','teat','proy','alum','music','club','vec','educ','muj','cole','salud','depor',
             'peña','tau','tor','enfer','sindr','danz','ecuest','manos','caz','herm','folc','desarr','futb','filo',
            'geo','derma','astro','mater','lit','consum','grup','pad','mad','diab','psico','san','jubil','animacion',
             'escler','internet','cuchill','scout','banda','eco','toxic','casin','mayor','poe','encaje','disca','galleg',
            'aliment','comision','tuna','linux','celiac','dona','pensi','cient','capac','liceo','ruta','fray','guiri',
             'medio ambiente','igual','cienc','siest','multiav','capa','turis','foto','hum','comit','down',
             'moro','folk','urol','trans','drog','flame','profes','corriente','benef','hombr','social','atl','tamb',
             'renac','taller','reti','escue','fibr','comerc','servic','preadop','viud','coro','estud','canci','oper',
             'matri','creat','diver','perc','coch','roq','puebl','madre','liri','socr','fest','terap','chara','esc','quim',
             'fisi','usua','epilep','cabañ','cánc','empr','usu','sativ','canna','vide','idea','depr','tur','campo','espirit',
            'microbio','volunt','gremi','parapl','margi','alzhe','patrim','ingen','art','bail','anore','finca','encin',
            'ciudad','cafe','sosten','infant','copla','ajed','colomb','orque','concier','ruman','femen','gitan','audio',
            'produc','hipotec','caball','patin','polici','museo','robado','vehíc','jamon','músic','vino','gait','hist','montañ',
             'pedagog','ritmo','enolog','ocio','batuca','electron','parkou','sinfon','propie','bici','carne','radio','food',
            'cine','suicidi','tai chi','edad','femi','libro','porcin','rock','juego','peregr','medioamb','palestin','latin',
            'blog','lupus','parkins','ornito','viaje','a.m.p.a','trasplant','sordo','biblio','fitness','pediatr','infan',
            'mot','cicl','biomedi','electr','feria','tecnol','étni','vacun','alcoho','abogad','guitarr','medic','empl',
            'niñ','labor','ambien','cuba','museu','vendor','industri','trabaj']

# %%
df = eliminar_filas_listanegra(df, listanegra)
print(len(list(df['nom_entitat'].unique())))
list(df['nom_entitat'].unique())
# Out:
# 2626
# ['Associació Terres del Gaià',
#  'Associació Alto al Mobbing',
#  'Associació Cal Temerari',
#  "Associació Gent Gran de l'Ametlla de Merola",
#  'Associació de Promoció de la Masoveria Urbana',
#  'Amics del Ripoll',
#  'Associació Mementu',
#  'Asoc. Emuna once',
#  'Associació Peluts de Navarcles',
#  'Associació Bigotitos de Àngel',
#  'Amics del Ball de Canet de Mar',
#  'Associació Els Nostres Petits',
#  'Associació Gat i Cua',
#  'Associació Adoptagat',
#  'Associació Col·leccionistes de Plaques de Cava de Manlleu - Acpcm',
#  'Col·legi Oficial de Detectius Privats de Catalunya',
#  'Associació de Concessionaris de Mercabarna (ASSOCOME)',
#  "Associació Aula d'Extensió Universitària d'Arenys de Mar",
#  'Asociación Hispano-china de Tai-chi, Wudang Quanfa Yanjiu Hui',
#  'Col·legi Oficial de Metges de Lleida',
#  'Associació Leyendo Perros',
#  'Associació Atanagrum',
#  "Associació PROFAUNA Terres de l'Ebre",
#  'Associació La Peludeta',
# ...

# %%
dog= extraer_por_palabra(df,'dog')
dog
# Out:
#       codi_postal  fax tipus_entitat        cif  \
# 22          17834  NaN    Associació  No consta
# 219         17600  NaN    Associació  No consta
# 682          8870  NaN    Associació  No consta
# 1181        43500  NaN    Associació  No consta
# 1515        43880  NaN    Associació  No consta
# 2172         8420  NaN    Associació  No consta
# 2230         8035  NaN    Associació  No consta
# 2961         8003  NaN    Associació  No consta
# 3448         8915  NaN    Associació  G66566332
# 4848        17404  NaN    Associació  No consta
# 5472        25700  NaN    Associació  No consta
# 6045        25718  NaN    Associació  G25860669
# 7298         8018  NaN    Associació  No consta
#
#                                             nom_entitat  \
# 22               Associació Cat&Dog del Pla de l'Estany
# 219                          Associació Tramuntana Dogs
# 682              Meparecequehevistounlindogatito Assoc.
# 1181                          Associació Ebre Dogs & Co
# ...

# %%
df_ok = pd.concat([df_ok , dog], axis=0)
df= restar_df(df, dog)

# %%
df_ok
# Out:
#       codi_postal  fax tipus_entitat        cif  \
# 52           8720  NaN    Associació  G66843608
# 66          25739  NaN    Associació  No consta
# 385          8811  NaN    Associació  G66665613
# 704          8329  NaN    Associació  G62241419
# 865         17004  NaN    Associació  G55365449
# ...           ...  ...           ...        ...
# 3448         8915  NaN    Associació  G66566332
# 4848        17404  NaN    Associació  No consta
# 5472        25700  NaN    Associació  No consta
# 6045        25718  NaN    Associació  G25860669
# 7298         8018  NaN    Associació  No consta
#
#                                             nom_entitat  \
# 52    Voluntacaad-Associació de Voluntaris del Centr...
# 66                 Associació Mon Animal del Colldelrat
# 385   Associació Amics dels Animals de Canyelles Hue...
# 704   Associació Teià per la Defensa dels Animals i ...
# 865           ASSOCIACIÓ PROJECTE LOLA, BENESTAR ANIMAL
# ...

# %% [markdown]
# GUARDO POR SI ACASO LOS DOS DF QUE TENGO, LOS IMPORTARÉ EN OTRO IPYNB PARA TRABAJAR CON ELLOS

# %%
# Guardar DataFrame en un archivo de Excel
df_ok.to_excel('asociaciones_cataluña_filtrado1_df_ok.xlsx', index=False)
df.to_excel('asociaciones_cataluña1_df.xlsx', index=False)
